# %% [markdown]
# ### Case Study 4 :  Data Science Shark Tank
#
# ***Due Date: December 3, 2025 before 11:59pm***
#
# Note:
#
# ***part_1 and part_3 of Problem_1, and links to datasets (or API you are planning to use) should be sent to me by email (tghoshal@wpi.edu) before 11:59pm on November 11. Without this step, your project may not be approved for presentation on April 23.You must CC all your group members in that email.***
#
# ***On November 13, we will have an 'Elevator Pitch' session.***
#
# also NOTE:
#
# 1. There are always last minute issues submitting the case studies. DO NOT WAIT UNTIL THE LAST MINUTE!
#
# 2. We may collect feedback after your submission to understand everyone's contributions. The feedback may affect your grade.

# %%
'''





'''
# Out:
# '\n\n\n\n\n\n'

# %% [markdown]
# ### Introduction
#
# After the previous 3 case studies,  your are now equipped with three powerful skills of an effective data scientist: ***data gathering, model development, exploratory data analysis***. In this case study, your team is going to act like a data science team in a mid-size company. Your team will make use of these skills to come up with an idea for a new data science project, covince senior executives of the idea to get funding/ financial resources using data driven presentations, and finally build a prototype model for use by another team within the company.
#
# Your team needs to decide which business problem is important for the market your company is in (for example, social media market, housing market, search market, etc.). Then use data science approaches to gather data, explore the data, tie with business needs, make conjectures, develop models etc.
#
# The solution should include some key components of data science:
#
#     1) the business part to analyze the potential impact of your new/improved service, why the idea can make money, how are you planning to persuade senior executives (e.g. seniors VPS/ CEO/ COO) to allocate money for your project
#
#     2) collect data, perform exploratory data analysis, make conjectures in support of the business plan made in the previous step.
#
#     3) Use one of your conjectures from step 2 as the motivation for developing a model. Use appropriate features from your data and build the model.
#
# NOTE, as opposed to the first three case studies, case study 4 is much much more open ended. A more complex model does not mean a better project. Also, strong exploratory data analysis loosely tied with the business question also does not mean a better project. Try to make all parts coherent so that they collectively tell one story.

# %% [markdown]
# # Background (Elevator Pitch)

# %%
# Should your project presentation be like this?

from IPython.display import YouTubeVideo
YouTubeVideo("7a_lu7ilpnI")

# %% [markdown]
# ## Some Resources
#
#
# **Optional Readings:**
#
#
# **APIs**
# * Zillow API: https://pypi.python.org/pypi/pyzillow
# * Google Map API: https://developers.google.com/api-client-library/python/apis/mapsengine/v1?hl=en
# * More APIs: https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition
#
# **Python libraries you may want to use:**
# * Scikit-learn (http://scikit-learn.org): machine learning tools in Python.
#
# **Data sources:**
# * UCI Machine Learning Repository: http://archive.ics.uci.edu/ml/
# * Statlib datasets: http://lib.stat.cmu.edu/datasets/
# * Kaggel: www.kaggle.com
# * Open Gov. Data: www.data.gov, www.data.gov.uk, https://www.data.gouv.fr/fr/, https://www.oecd.org/gov/digital-government/open-government-data.htm

# %% [markdown]
# ### Problem 1: the Business Part (20 points)
#  As a group, learn about the data science related business and research about the current markets: such as search, social media, advertisement, recommendation and so on. Pick one of the markets for further consideration, and propose a new data science project which you believe will be important for your company to do well in the market. Define precisely in the report and briefly in the cells below, what is the business problem that your team wants to solve.
# Why the problem is important to solve?
# Why you believe your team can make use of data science methodologies to solve the problem?
# How are you planing to persuade the senior executives to buy in your idea.

# %% [markdown]
# **Please describe here *briefly*  (please edit this cell)**
#
# 1) Your business problem to solve:
#
#
#
# 2) Why the problem is important to solve?
#
#
# 3) What is your idea to solve the problem?
#
#
# 4) What differences you could make with your data science approach?
#
#
# 5) Why do you believe the idea deserves the financial resources of your company?

# %% [markdown]
# ### Problem 2: Data Gathering, Exploratory Data Analysis, Make Conjectures (20 points)
#
# Gather data in support of your responses for Problem 1. Use appropriate data analysis techniques to explore the data. Make conejectures in relation to problem 1. Find support for your conjectures using the data.

# %% [markdown]
# **Insert your answers in the cell below**
#
# **Add as many cells as needed**
#
#
# If you are using an API to collect data, provide the code below.
#
# If you collecting data from publicly available datasets, provide the links to them below.

# %%
# - Tristan - API key (newsAPI) - 78fc48a18a074927ab98ea7c487bfd4b

import pandas as pd
import numpy as np

newsapi = NewsApiClient(api_key='78fc48a18a074927ab98ea7c487bfd4b')
print(newsapi)

# can only get last 30 day of data without paying
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2413101904.py in <cell line: 0>()
#       3 import pandas as pd
#       4 import numpy as np
# ----> 5 from newsapi import NewsApiClient
#       6
#       7 newsapi = NewsApiClient(api_key='78fc48a18a074927ab98ea7c487bfd4b')
#
# ModuleNotFoundError: No module named 'newsapi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#GDELT Global News - set up

from google.cloud import bigquery
import os


#import key file on Windows
#os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "D:\\Users\\Tris\\Downloads\\tsla-sentiment-608253418e5c.json"

#importing key file on Mac
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "tsla-sentiment-608253418e5c.json"


# https://console.cloud.google.com/welcome/new?project=tsla-sentiment
# https://huggingface.co/ProsusAI/finbert
# https://console.cloud.google.com/iam-admin/serviceaccounts?project=tsla-sentiment&supportedpurview=project

# %%
START_DATE = 20220101
END_DATE   = 20241231

query_tsla_us_events = f"""
WITH base AS (
  SELECT
    DATE(
      PARSE_DATE('%Y%m%d', CAST(SQLDATE AS STRING))
    ) AS day,

    -- Core event-level sentiment / intensity
    AvgTone,
    GoldsteinScale,
    NumMentions,
    NumSources,
    NumArticles,

    -- Actors & URL
    LOWER(Actor1Name) AS a1_name,
    LOWER(Actor2Name) AS a2_name,
    SOURCEURL         AS url,

    ActionGeo_CountryCode AS action_country,

    -- Flags for TSLA
    (
      (LOWER(Actor1Name) LIKE '%tesla%') OR
      (LOWER(Actor2Name) LIKE '%tesla%') OR
      (LOWER(SOURCEURL)  LIKE '%tesla%')
    ) AS is_tsla_event,

    -- EV industry events (URL heuristic)
    (
      LOWER(SOURCEURL) LIKE '%electric-vehicle%'  OR
      LOWER(SOURCEURL) LIKE '%electric-vehicles%' OR
      LOWER(SOURCEURL) LIKE '%electric-car%'      OR
      LOWER(SOURCEURL) LIKE '%electric-cars%'     OR
      LOWER(SOURCEURL) LIKE '%ev-battery%'        OR
      LOWER(SOURCEURL) LIKE '%ev-industry%'       OR
      LOWER(SOURCEURL) LIKE '%battery-electric%'  OR
      LOWER(SOURCEURL) LIKE '%plug-in-hybrid%'
    ) AS is_ev_event,

    -- Macro / market-wide financial events
    (
      -- Fed / interest rates / yields
      LOWER(SOURCEURL) LIKE '%federal-reserve%'   OR
      LOWER(SOURCEURL) LIKE '%fomc%'              OR
      LOWER(SOURCEURL) LIKE '%interest-rate%'     OR
      LOWER(SOURCEURL) LIKE '%rate-hike%'         OR
      LOWER(SOURCEURL) LIKE '%rate-cut%'          OR
      LOWER(SOURCEURL) LIKE '%treasury-yield%'    OR
      LOWER(SOURCEURL) LIKE '%bond-yield%'        OR

      -- Inflation / CPI / prices
      LOWER(SOURCEURL) LIKE '%inflation%'         OR
      LOWER(SOURCEURL) LIKE '%cpi%'               OR
      LOWER(SOURCEURL) LIKE '%consumer-price%'    OR

      -- Jobs / unemployment
      LOWER(SOURCEURL) LIKE '%jobs-report%'       OR
      LOWER(SOURCEURL) LIKE '%payrolls%'          OR
      LOWER(SOURCEURL) LIKE '%nonfarm-payrolls%'  OR
      LOWER(SOURCEURL) LIKE '%unemployment-rate%' OR

      -- Growth / recession
      LOWER(SOURCEURL) LIKE '%gdp%'               OR
      LOWER(SOURCEURL) LIKE '%recession%'         OR
      LOWER(SOURCEURL) LIKE '%economic-growth%'   OR

      -- Broad stock market moves
      LOWER(SOURCEURL) LIKE '%stock-market%'      OR
      LOWER(SOURCEURL) LIKE '%wall-street%'       OR
      LOWER(SOURCEURL) LIKE '%market-rout%'       OR
      LOWER(SOURCEURL) LIKE '%market-rally%'
    ) AS is_macro_event

  FROM `gdelt-bq.gdeltv2.events`
  WHERE
    SQLDATE BETWEEN {START_DATE} AND {END_DATE}
    AND ActionGeo_CountryCode = 'US'
    AND (
      -- TSLA
      LOWER(Actor1Name) LIKE '%tesla%' OR
      LOWER(Actor2Name) LIKE '%tesla%' OR
      LOWER(SOURCEURL)  LIKE '%tesla%' OR

      -- EV URLs
      LOWER(SOURCEURL)  LIKE '%electric-vehicle%'  OR
      LOWER(SOURCEURL)  LIKE '%electric-vehicles%' OR
      LOWER(SOURCEURL)  LIKE '%electric-car%'      OR
      LOWER(SOURCEURL)  LIKE '%electric-cars%'     OR
      LOWER(SOURCEURL)  LIKE '%ev-battery%'        OR
      LOWER(SOURCEURL)  LIKE '%ev-industry%'       OR
      LOWER(SOURCEURL)  LIKE '%battery-electric%'  OR
      LOWER(SOURCEURL)  LIKE '%plug-in-hybrid%' OR

      -- Macro-only rows (so you get market context even without TSLA/EV mention)
      LOWER(SOURCEURL)  LIKE '%federal-reserve%'   OR
      LOWER(SOURCEURL)  LIKE '%fomc%'              OR
      LOWER(SOURCEURL)  LIKE '%interest-rate%'     OR
      LOWER(SOURCEURL)  LIKE '%rate-hike%'         OR
      LOWER(SOURCEURL)  LIKE '%rate-cut%'          OR
      LOWER(SOURCEURL)  LIKE '%treasury-yield%'    OR
      LOWER(SOURCEURL)  LIKE '%bond-yield%'        OR
      LOWER(SOURCEURL)  LIKE '%inflation%'         OR
      LOWER(SOURCEURL)  LIKE '%cpi%'               OR
      LOWER(SOURCEURL)  LIKE '%consumer-price%'    OR
      LOWER(SOURCEURL)  LIKE '%jobs-report%'       OR
      LOWER(SOURCEURL)  LIKE '%payrolls%'          OR
      LOWER(SOURCEURL)  LIKE '%nonfarm-payrolls%'  OR
      LOWER(SOURCEURL)  LIKE '%unemployment-rate%' OR
      LOWER(SOURCEURL)  LIKE '%gdp%'               OR
      LOWER(SOURCEURL)  LIKE '%recession%'         OR
      LOWER(SOURCEURL)  LIKE '%economic-growth%'   OR
      LOWER(SOURCEURL)  LIKE '%stock-market%'      OR
      LOWER(SOURCEURL)  LIKE '%wall-street%'       OR
      LOWER(SOURCEURL)  LIKE '%market-rout%'       OR
      LOWER(SOURCEURL)  LIKE '%market-rally%'
    )
)

SELECT
  day,

  -- ==========================
  -- TSLA metrics
  -- ==========================
  AVG(CASE WHEN is_tsla_event THEN AvgTone END)        AS tsla_event_tone,
  AVG(CASE WHEN is_tsla_event THEN GoldsteinScale END) AS tsla_goldstein,
  COUNTIF(is_tsla_event)                               AS tsla_event_count,

  SAFE_DIVIDE(
    SUM(CASE WHEN is_tsla_event THEN AvgTone * NumArticles END),
    NULLIF(SUM(CASE WHEN is_tsla_event THEN NumArticles END), 0)
  ) AS tsla_article_weighted_tone,

  SUM(CASE WHEN is_tsla_event THEN NumArticles END) AS tsla_num_articles,
  SUM(CASE WHEN is_tsla_event THEN NumSources  END) AS tsla_num_sources,

  -- ==========================
  -- EV metrics
  -- ==========================
  AVG(CASE WHEN is_ev_event THEN AvgTone END)        AS ev_event_tone,
  AVG(CASE WHEN is_ev_event THEN GoldsteinScale END) AS ev_goldstein,
  COUNTIF(is_ev_event)                               AS ev_event_count,

  SAFE_DIVIDE(
    SUM(CASE WHEN is_ev_event THEN AvgTone * NumArticles END),
    NULLIF(SUM(CASE WHEN is_ev_event THEN NumArticles END), 0)
  ) AS ev_article_weighted_tone,

  SUM(CASE WHEN is_ev_event THEN NumArticles END) AS ev_num_articles,
  SUM(CASE WHEN is_ev_event THEN NumSources  END) AS ev_num_sources,

  -- ==========================
  -- Macro / market metrics
  -- ==========================
  AVG(CASE WHEN is_macro_event THEN AvgTone END)        AS macro_event_tone,
  AVG(CASE WHEN is_macro_event THEN GoldsteinScale END) AS macro_goldstein,
  COUNTIF(is_macro_event)                               AS macro_event_count,

  SAFE_DIVIDE(
    SUM(CASE WHEN is_macro_event THEN AvgTone * NumArticles END),
    NULLIF(SUM(CASE WHEN is_macro_event THEN NumArticles END), 0)
  ) AS macro_article_weighted_tone,

  SUM(CASE WHEN is_macro_event THEN NumArticles END) AS macro_num_articles,
  SUM(CASE WHEN is_macro_event THEN NumSources  END) AS macro_num_sources,

  -- ==========================
  -- URL arrays
  -- ==========================
  ARRAY_AGG(DISTINCT IF(is_tsla_event,   url, NULL) IGNORE NULLS) AS tsla_event_urls,
  ARRAY_AGG(DISTINCT IF(is_ev_event,     url, NULL) IGNORE NULLS) AS ev_event_urls,
  ARRAY_AGG(DISTINCT IF(is_macro_event,  url, NULL) IGNORE NULLS) AS macro_event_urls

FROM base
GROUP BY day
ORDER BY day
"""



def estimate_bytes(query: str):
    """Dry-run a query and print how many GB it would scan."""

    client = bigquery.Client(project="tsla-sentiment")
    job_config = bigquery.QueryJobConfig(
        dry_run=True,
        use_query_cache=False)
    query_job = client.query(query, job_config=job_config)
    gb = query_job.total_bytes_processed / (1e9)
    COST_PER_GB = 0.005  # USD
    print(f"Estimated size of data processed: {gb:.2f} GB\nEstimated cost: ${gb*COST_PER_GB:.2f} USD")

def run_guarded_query(query: str, max_gb: float = 1.0):
    client = bigquery.Client(project="tsla-sentiment")

    job_config = bigquery.QueryJobConfig(
        maximum_bytes_billed=int(max_gb * 1e9) #convert GB -> bytes
    )
    query_job = client.query(query, job_config=job_config)
    return query_job.to_dataframe()


estimate_bytes(query_tsla_us_events)

# Commenting out actual query to avoid accidental costs

# df = run_guarded_query(query_tsla_us_events, max_gb=140.0)
# df.to_parquet("tsla_events.parquet")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# /tmp/ipython-input-811370128.py in <cell line: 0>()
#     205
#     206
# --> 207 estimate_bytes(query_tsla_us_events)
#     208
#     209 # Commenting out actual query to avoid accidental costs
#
# /tmp/ipython-input-811370128.py in estimate_bytes(query)
#     186     """Dry-run a query and print how many GB it would scan."""
#     187
# --> 188     client = bigquery.Client(project="tsla-sentiment")
#     189     job_config = bigquery.QueryJobConfig(
#     190         dry_run=True,
#
# /usr/local/lib/python3.12/dist-packages/google/cloud/bigquery/client.py in __init__(self, project, credentials, _http, location, default_query_job_config, default_load_job_config, client_info, client_options, default_job_creation_mode)
#     259         # assert isinstance(client_options, google.api_core.client_options.ClientOptions)
#     260
# --> 261         super(Client, self).__init__(
#     262             project=project,
#     263             credentials=credentials,
#
# /usr/local/lib/python3.12/dist-packages/google/cloud/client/__init__.py in __init__(self, project, credentials, client_options, _http)
#     338     def __init__(self, project=None, credentials=None, client_options=None, _http=None):
#     339         _ClientProjectMixin.__init__(self, project=project, credentials=credentials)
# --> 340         Client.__init__(
#     341             self, credentials=credentials, client_options=client_options, _http=_http
#     342         )
#
# /usr/local/lib/python3.12/dist-packages/google/cloud/client/__init__.py in __init__(self, credentials, _http, client_options)
#     195                 credentials = google.auth.api_key.Credentials(client_options.api_key)
#     196             else:
# --> 197                 credentials, _ = google.auth.default(scopes=scopes)
#     198
#     199         self._credentials = google.auth.credentials.with_scopes_if_required(
#
# /usr/local/lib/python3.12/dist-packages/google/auth/_default.py in default(scopes, request, quota_project_id, default_scopes)
#     683
#     684     for checker in checkers:
# --> 685         credentials, project_id = checker()
#     686         if credentials is not None:
#     687             credentials = with_scopes_if_required(
#
# /usr/local/lib/python3.12/dist-packages/google/auth/_default.py in <lambda>()
#     676         # safely set on the returned credentials since requires_scopes will
#     677         # guard against setting scopes on user credentials.
# --> 678         lambda: _get_explicit_environ_credentials(quota_project_id=quota_project_id),
#     679         lambda: _get_gcloud_sdk_credentials(quota_project_id=quota_project_id),
#     680         _get_gae_credentials,
#
# /usr/local/lib/python3.12/dist-packages/google/auth/_default.py in _get_explicit_environ_credentials(quota_project_id)
#     291
#     292     if explicit_file is not None:
# --> 293         credentials, project_id = load_credentials_from_file(
#     294             os.environ[environment_vars.CREDENTIALS], quota_project_id=quota_project_id
#     295         )
#
# /usr/local/lib/python3.12/dist-packages/google/auth/_default.py in load_credentials_from_file(filename, scopes, default_scopes, quota_project_id, request)
#     123     """
#     124     if not os.path.exists(filename):
# --> 125         raise exceptions.DefaultCredentialsError(
#     126             "File {} was not found.".format(filename)
#     127         )
#
# DefaultCredentialsError: File tsla-sentiment-608253418e5c.json was not found.

# %%
df = pd.read_parquet("tsla_events.parquet")
df.to_csv("tsla_events.csv",index=False)


numerical_cols = df.select_dtypes(include="number").columns
df[numerical_cols] = df[numerical_cols].fillna(0)

df.head()
# Out:
#           day  tsla_event_tone  tsla_goldstein  tsla_event_count  \
# 0  2022-01-01         0.644375       -0.860000                10
# 1  2022-01-02         0.617553       -0.575000                 8
# 2  2022-01-03         0.659130        1.336000                25
# 3  2022-01-04        -3.380245       -1.013208               106
# 4  2022-01-05        -3.704642        0.764198                81
#
#    tsla_article_weighted_tone  tsla_num_articles  tsla_num_sources  \
# 0                   -0.084738                 53                10
# 1                    0.255846                 30                 8
# 2                    0.399531                112                25
# 3                   -3.523362                352               106
# 4                   -3.703005                344                98
#
#    ev_event_tone  ev_goldstein  ev_event_count  ...  ev_num_sources  \
# 0       0.000000      0.000000               0  ...               0
# 1      -0.789993      4.950000               4  ...               4
# 2      -0.987384      2.337500               8  ...               8
# 3       0.886971      1.280000              10  ...              10
# 4       0.662207      3.753333              15  ...              15
#
#    macro_event_tone  macro_goldstein  macro_event_count  \
# 0         -5.314509         0.500000                  2
# 1          0.090435         1.363636                 33
# 2          0.552264         3.504762                 42
# 3         -2.053667         3.116667                 12
# 4         -3.037548         2.371429                 21
#
#    macro_article_weighted_tone  macro_num_articles  macro_num_sources  \
# 0                    -5.314509                  20                  2
# 1                     0.029522                 134                 33
# 2                     0.584197                 192                 42
# 3                    -2.317356                  85                 12
# 4                    -3.338758                  94                 21
#
#                                      tsla_event_urls  \
# 0  [https://www.investor.bg/novini/444/a/tesla-sy...
# 1  [https://www.tribuneindia.com/news/nation/indi...
# 2  [https://www.aljazeera.com/economy/2022/1/3/te...
# 3  [https://www.theverge.com/22865603/gaf-energy-...
# 4  [https://zeenews.india.com/companies/meet-asho...
#
#                                        ev_event_urls  \
# 0                                                 []
# 1  [https://www.msn.com/en-us/autos/news/electric...
# 2  [https://buffalonews.com/news/local/canada-say...
# 3  [https://soyacincau.com/2022/01/04/apple-becam...
# 4  [https://oilprice.com/Energy/Crude-Oil/The-Big...
#
#                                     macro_event_urls
# 0  [https://www.investing.com/news/stock-market-n...
# 1  [https://www.huewire.com/re-turkey-finance-min...
# 2  [https://therealdeal.com/2022/01/03/top-banks-...
# 3  [https://www.chron.com/business/article/Amgen-...
# 4  [https://www.businesstoday.in/coronavirus/stor...
#
# [5 rows x 22 columns]

# %%
df.info()
df.describe()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096 entries, 0 to 1095
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   day                          1096 non-null   dbdate
#  1   tsla_event_tone              1096 non-null   float64
#  2   tsla_goldstein               1096 non-null   float64
#  3   tsla_event_count             1096 non-null   Int64
#  4   tsla_article_weighted_tone   1096 non-null   float64
#  5   tsla_num_articles            1096 non-null   Int64
#  6   tsla_num_sources             1096 non-null   Int64
#  7   ev_event_tone                1067 non-null   float64
#  8   ev_goldstein                 1067 non-null   float64
#  9   ev_event_count               1096 non-null   Int64
#  10  ev_article_weighted_tone     1067 non-null   float64
#  11  ev_num_articles              1067 non-null   Int64
#  12  ev_num_sources               1067 non-null   Int64
#  13  macro_event_tone             1095 non-null   float64
#  14  macro_goldstein              1095 non-null   float64
#  15  macro_event_count            1096 non-null   Int64
#  16  macro_article_weighted_tone  1095 non-null   float64
#  17  macro_num_articles           1095 non-null   Int64
#  18  macro_num_sources            1095 non-null   Int64
#  19  tsla_event_urls              1096 non-null   object
#  20  ev_event_urls                1096 non-null   object
#  21  macro_event_urls             1096 non-null   object
# dtypes: Int64(9), dbdate(1), float64(9), object(3)
# memory usage: 198.1+ KB
#           day  tsla_event_tone  tsla_goldstein  tsla_event_count  \
# 0  2022-01-01         0.644375       -0.860000                10
# 1  2022-01-02         0.617553       -0.575000                 8
# 2  2022-01-03         0.659130        1.336000                25
# 3  2022-01-04        -3.380245       -1.013208               106
# 4  2022-01-05        -3.704642        0.764198                81
#
#    tsla_article_weighted_tone  tsla_num_articles  tsla_num_sources  \
# 0                   -0.084738                 53                10
# 1                    0.255846                 30                 8
# 2                    0.399531                112                25
# 3                   -3.523362                352               106
# 4                   -3.703005                344                98
#
#    ev_event_tone  ev_goldstein  ev_event_count  ...  ev_num_sources  \
# 0            NaN           NaN               0  ...            <NA>
# 1      -0.789993      4.950000               4  ...               4
# 2      -0.987384      2.337500               8  ...               8
# 3       0.886971      1.280000              10  ...              10
# 4       0.662207      3.753333              15  ...              15
#
#    macro_event_tone  macro_goldstein  macro_event_count  \
# 0         -5.314509         0.500000                  2
# 1          0.090435         1.363636                 33
# 2          0.552264         3.504762                 42
# 3         -2.053667         3.116667                 12
# 4         -3.037548         2.371429                 21
#
#    macro_article_weighted_tone  macro_num_articles  macro_num_sources  \
# 0                    -5.314509                  20                  2
# 1                     0.029522                 134                 33
# 2                     0.584197                 192                 42
# 3                    -2.317356                  85                 12
# 4                    -3.338758                  94                 21
#
#                                      tsla_event_urls  \
# 0  [https://www.investor.bg/novini/444/a/tesla-sy...
# 1  [https://www.tribuneindia.com/news/nation/indi...
# 2  [https://www.aljazeera.com/economy/2022/1/3/te...
# 3  [https://www.theverge.com/22865603/gaf-energy-...
# 4  [https://zeenews.india.com/companies/meet-asho...
#
#                                        ev_event_urls  \
# 0                                                 []
# 1  [https://www.msn.com/en-us/autos/news/electric...
# 2  [https://buffalonews.com/news/local/canada-say...
# 3  [https://soyacincau.com/2022/01/04/apple-becam...
# 4  [https://oilprice.com/Energy/Crude-Oil/The-Big...
#
#                                     macro_event_urls
# 0  [https://www.investing.com/news/stock-market-n...
# 1  [https://www.huewire.com/re-turkey-finance-min...
# 2  [https://therealdeal.com/2022/01/03/top-banks-...
# 3  [https://www.chron.com/business/article/Amgen-...
# 4  [https://www.businesstoday.in/coronavirus/stor...
#
# [5 rows x 22 columns]

# %%
int(df['ev_event_count'].sum())
# Out:
# 18811

# %%
# https://huggingface.co/ProsusAI/finbert


# Use a pipeline as a high-level helper

# from transformers import pipeline

# pipe = pipeline("text-classification", model="ProsusAI/finbert")

# %%
# 1. Install and import libraries

# Run this once (in a notebook cell)
# !pip install pandas requests beautifulsoup4 transformers torch --quiet

import pandas as pd          # work with tables
import requests              # download web pages
from bs4 import BeautifulSoup  # extract text from HTML
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
import ast                   # to convert string → Python list safely

# %%
# 2. Load tsla_events.csv

# Make sure tsla_events.csv is in your current working folder
df = pd.read_csv("/content/tsla_events.csv")

print("Columns in file:")
print(df.columns)

# Look at first few rows just to confirm
df.head()
# Out:
# Columns in file:
# Index(['day', 'tsla_event_tone', 'tsla_goldstein', 'tsla_event_count',
#        'tsla_article_weighted_tone', 'tsla_num_articles', 'tsla_num_sources',
#        'ev_event_tone', 'ev_goldstein', 'ev_event_count',
#        'ev_article_weighted_tone', 'ev_num_articles', 'ev_num_sources',
#        'macro_event_tone', 'macro_goldstein', 'macro_event_count',
#        'macro_article_weighted_tone', 'macro_num_articles',
#        'macro_num_sources', 'tsla_event_urls', 'ev_event_urls',
#        'macro_event_urls'],
#       dtype='object')
#           day  tsla_event_tone  tsla_goldstein  tsla_event_count  \
# 0  2022-01-01         0.644375       -0.860000                10
# 1  2022-01-02         0.617553       -0.575000                 8
# 2  2022-01-03         0.659130        1.336000                25
# 3  2022-01-04        -3.380245       -1.013208               106
# 4  2022-01-05        -3.704642        0.764198                81
#
#    tsla_article_weighted_tone  tsla_num_articles  tsla_num_sources  \
# 0                   -0.084738                 53                10
# 1                    0.255846                 30                 8
# 2                    0.399531                112                25
# 3                   -3.523362                352               106
# 4                   -3.703005                344                98
#
#    ev_event_tone  ev_goldstein  ev_event_count  ...  ev_num_sources  \
# 0            NaN           NaN               0  ...             NaN
# 1      -0.789993      4.950000               4  ...             4.0
# 2      -0.987384      2.337500               8  ...             8.0
# 3       0.886971      1.280000              10  ...            10.0
# 4       0.662207      3.753333              15  ...            15.0
#
#    macro_event_tone  macro_goldstein  macro_event_count  \
# 0         -5.314509         0.500000                  2
# 1          0.090435         1.363636                 33
# 2          0.552264         3.504762                 42
# 3         -2.053667         3.116667                 12
# 4         -3.037548         2.371429                 21
#
#    macro_article_weighted_tone  macro_num_articles  macro_num_sources  \
# 0                    -5.314509                20.0                2.0
# 1                     0.029522               134.0               33.0
# 2                     0.584197               192.0               42.0
# 3                    -2.317356                85.0               12.0
# 4                    -3.338758                94.0               21.0
#
#                                      tsla_event_urls  \
# 0  ['https://www.investor.bg/novini/444/a/tesla-s...
# 1  ['https://www.tribuneindia.com/news/nation/ind...
# 2  ['https://www.aljazeera.com/economy/2022/1/3/t...
# 3  ['https://www.theverge.com/22865603/gaf-energy...
# 4  ['https://zeenews.india.com/companies/meet-ash...
#
#                                        ev_event_urls  \
# 0                                                 []
# 1  ['https://www.msn.com/en-us/autos/news/electri...
# 2  ['https://buffalonews.com/news/local/canada-sa...
# 3  ['https://soyacincau.com/2022/01/04/apple-beca...
# 4  ['https://oilprice.com/Energy/Crude-Oil/The-Bi...
#
#                                     macro_event_urls
# 0  ['https://www.investing.com/news/stock-market-...
# 1  ['https://www.huewire.com/re-turkey-finance-mi...
# 2  ['https://therealdeal.com/2022/01/03/top-banks...
# 3  ['https://www.chron.com/business/article/Amgen...
# 4  ['https://www.businesstoday.in/coronavirus/sto...
#
# [5 rows x 22 columns]

# %%
# 3. Extract tsla_event_urls as one URL per row

# Keep only the date and the TSLA URL list column
url_df = df[["day", "tsla_event_urls"]].copy()

# Replace missing values with empty lists in string form
url_df["tsla_event_urls"] = url_df["tsla_event_urls"].fillna("[]")

# Convert the string representation of list into real Python lists
# Example: '["url1","url2"]'  →  ["url1", "url2"]
url_df["tsla_event_urls"] = url_df["tsla_event_urls"].apply(ast.literal_eval)

# "Explode" so that each URL becomes one row
url_df = url_df.explode("tsla_event_urls")

# Rename the column to "url" for simplicity
url_df = url_df.rename(columns={"tsla_event_urls": "url"})

# Remove rows where URL is missing
url_df = url_df.dropna(subset=["url"])

# Remove duplicate URLs (optional but recommended)
url_df = url_df.drop_duplicates(subset=["url"])

print("Number of unique TSLA URLs:", len(url_df))
url_df.head()
# Out:
# Number of unique TSLA URLs: 1096
#           day                                                url
# 0  2022-01-01  https://www.investor.bg/novini/444/a/tesla-sys...
# 1  2022-01-02  https://www.tribuneindia.com/news/nation/india...
# 2  2022-01-03  https://www.aljazeera.com/economy/2022/1/3/tes...
# 3  2022-01-04  https://www.theverge.com/22865603/gaf-energy-t...
# 4  2022-01-05  https://zeenews.india.com/companies/meet-ashok...

# %%
# ============================================
# 4. Download article text for each URL
#    (simple version: grab visible text from page)
# ============================================

# To avoid huge runtime, you can limit how many you process at first:
# e.g., use .head(50) while testing, then remove .head(50) later.
url_sample = url_df.head(50).copy()   # change 50 → larger number later

texts = []   # to store article text

for i in range(len(url_sample)):
    url = url_sample.iloc[i]["url"]
    print(f"Fetching ({i+1}/{len(url_sample)}):", url)

    try:
        response = requests.get(url, timeout=10)
        html = response.text

        # Use BeautifulSoup to get raw text from the HTML
        soup = BeautifulSoup(html, "html.parser")

        # Very simple: get all text from the page
        page_text = soup.get_text(separator=" ", strip=True)

        # Optional: limit to first N characters so it's not too long for FinBERT
        page_text = page_text[:3000]   # keep first 3000 characters

    except Exception as e:
        print("Error fetching URL:", e)
        page_text = ""

    texts.append(page_text)

# Add the scraped text into the DataFrame
url_sample["raw_text"] = texts

# See what we got
url_sample[["day", "url", "raw_text"]].head()
# Out:
# Fetching (1/50): https://www.investor.bg/novini/444/a/tesla-sys-servizna-akciia-i-v-kitai-342841/https://www.nbclosangeles.com/news/business/money-report/tesla-energy-asks-employees-to-fight-policy-proposal-that-would-make-rooftop-solar-more-expensive-in-california/2788955/https://cleantechnica.com/2021/12/31/the-minigun-tesla-is-cool-but-real-military-evs-are-sorely-needed-in-2022/https://www.freepressjournal.in/world/tesla-ceo-elon-musk-advices-young-people-to-learn-as-much-as-possible
# Fetching (2/50): https://www.tribuneindia.com/news/nation/indian-origin-ashok-elluswamy-was-first-employee-to-be-hired-for-teslas-autopilot-team-elon-musk-357346https://www.msn.com/en-us/autos/news/tesla-delivered-close-to-one-million-vehicles-in-2021/ar-AASmHKvhttps://www.cnn.com/2022/01/02/investing/elon-musk-tesla-stock-sales-spacex-investment/https://menafn.com/1103474074/Heres-how-Musk-hired-Indian-origin-Teslas-autopilot-head&source=22
# Fetching (3/50): https://www.aljazeera.com/economy/2022/1/3/tesla-shares-charge-higher-on-record-q4-deliverieshttps://www.investing.com/news/stock-market-news/premarket-movers-tesla-jumps-ford-boeing-rise-ross-stores-dips-2728849https://www.nbcphiladelphia.com/news/business/money-report/ford-beats-out-tesla-to-become-the-auto-industrys-top-growth-stock-in-2021/3095223/https://indianewengland.com/2022/01/heres-how-musk-hired-indian-origin-teslas-autopilot-head/https://www.theverge.com/2022/1/2/22863751/tesla-delivered-one-million-vehicles-2021https://www.dailymail.co.uk/news/article-10363361/Tesla-says-delivered-record-936K-vehicles-2021-87.htmlhttps://www.peru-retail.com/este-es-el-robot-humanoide-de-tesla-que-hara-las-compras-por-usted/https://www.gobankingrates.com/saving-money/home/tesla-fights-california-law-that-could-make-solar-energy-costs-soar/https://www.bloombergquint.com/business/musk-calls-infamous-take-tesla-private-tweet-entirely-truthfulhttps://www.washingtonexaminer.com/news/elon-musk-launches-tesla-showroom-in-xinjiang-amid-uyghur-genocide-allegations
# Fetching (4/50): https://www.theverge.com/22865603/gaf-energy-timberline-solar-shingle-panel-roof-ul-teslahttps://www.startribune.com/tesla-odp-rise-applied-therapeutics-newmont-fall/600132334/https://www.breitbart.com/asia/2022/01/03/elon-musk-opens-tesla-store-in-xinjiang-chinas-concentration-camp-region/https://www.dailymail.co.uk/tvshowbiz/article-10369191/Amber-Heard-drives-Tesla-ex-boyfriend-Elon-Musk-gifted-her.htmlhttps://www.torquenews.com/11826/tesla-tsla-shares-surges-following-record-q4-deliveries-and-end-elon-musk-s-stock-salehttps://www.npr.org/2022/01/04/1070119371/activists-urge-tesla-to-close-its-new-xinjiang-showroomhttps://www.ndtv.com/world-news/us-news-china-news-tesla-showroom-in-xinjiang-tesla-under-fire-for-new-showroom-in-chinas-controversial-xinjiang-area-2687863https://tvn24.pl/swiat/sinciang-tesla-oskarzona-o-wspieranie-ludobojstwa-5548505https://www.theguardian.com/world/2022/jan/04/tesla-criticised-for-opening-showroom-in-xinjiang-despite-human-rights-abuseshttps://economictimes.indiatimes.com/news/international/world-news/activists-call-on-tesla-to-close-new-xinjiang-showroom/articleshow/88683557.cmshttps://www.dailymail.co.uk/news/article-10368367/Elon-Musk-accused-economic-support-genocide-opening-Tesla-showroom-Chinas-Xinjiang.htmlhttps://houstonianonline.com/tesla-has-come-under-heavy-criticism-in-the-united-states-for-opening-a-showroom-in-xinjiang/https://www.theepochtimes.com/tesla-criticised-after-opening-showroom-in-xinjiang_4192736.htmlhttps://www.marketwatch.com/story/tesla-opens-showroom-in-xinjiang-the-chinese-region-associated-with-genocide-allegations-11641259484https://www.business-standard.com/article/international/how-tesla-weathered-global-supply-chain-issues-that-knocked-rivals-122010401070_1.htmlhttps://www.rp.pl/biznes/art19255281-tesla-skrytykowana-za-otwarcie-placowki-w-sinkianguhttps://www.myplainview.com/news/article/Activists-call-on-Tesla-to-close-new-Xinjiang-16747433.phphttps://www.abqjournal.com/2458658/activists-urge-tesla-to-close-new-xinjiang-showroom.htmlhttps://insideevs.com/features/558616/rivian-future-follow-tesla-success/https://www.marketscreener.com/quote/stock/HENNES-MAURITZ-AB-6491104/news/Tesla-criticised-for-opening-showroom-in-China-s-Xinjiang-region-37458346/https://www.brisbanetimes.com.au/business/companies/tesla-criticised-for-opening-showroom-in-china-s-xinjiang-region-20220105-p59lxa.htmlhttps://techstory.in/ford-is-boosting-ev-sales-in-locations-where-tesla-is-not-popular/https://www.latimes.com/world-nation/story/2022-01-04/activists-urge-tesla-close-xinjiang-china-showroomhttps://wdsm710.com/2022/01/04/explainer-how-tesla-weathered-global-supply-chain-issues-that-knocked-rivals/https://nieuws.nl/economie/20220104/tesla-onder-vuur-in-vs-vanwege-opening-showroom-in-xinjiang/https://business.inquirer.net/338173/tesla-showroom-in-chinas-xinjiang-region-blasted-by-rights-groupshttps://investir.lesechos.fr/actions/actualites/tesla-sous-le-feu-des-critiques-apres-avoir-annonce-l-ouverture-d-une-concession-au-xinjiang-1995898.phphttps://www.winnipegfreepress.com/business/activists-call-on-tesla-to-close-new-xinjiang-showroom-576005902.htmlhttps://www.marketscreener.com/quote/stock/TESLA-INC-6344549/news/Activists-call-on-Tesla-to-close-new-Xinjiang-showroom-37457639/https://www.newsit.gr/auto/kraksimo-stin-Tesla-epeidi-anoikse-ekthesiako-xoro-stin-sintziangk/3440486/https://www.sowetanlive.co.za/business/2022-01-04-tesla-criticised-for-opening-showroom-in-chinas-xinjiang-region/https://katcountry989.com/2022/01/04/tesla-criticised-for-opening-showroom-in-chinas-xinjiang-region/https://www.marketingdive.com/news/legacy-auto-brands-chase-Tesla-on-EVs/616453/https://www.wnp.pl/rynki-zagraniczne/usa-tesla-w-ogniu-krytyki-po-otwarciu-salonu-wystawowego-w-chinskim-sinciangu,524021.htmlhttps://www.nbcnews.com/news/world/tesla-criticized-new-showroom-chinas-xinjiang-region-rcna10828
# Fetching (5/50): https://zeenews.india.com/companies/meet-ashok-elluswamy-indian-origin-teslas-autopilot-head-and-know-how-elon-musk-hired-him-2425450.htmlhttps://www.boersennews.de/nachrichten/artikel/tesla-wegen-neuen-gesch-fts-in-xinjiang-in-der-kritik/3402666/https://www.breitbart.com/national-security/2022/01/04/human-rights-activists-condemn-elon-musk-for-supporting-genocide-with-tesla-xinjiang-store/https://otomotif.antaranews.com/berita/2624877/tesla-buka-showroom-di-xinjiang-as-beri-sinyal-tak-senanghttps://www.courrierinternational.com/article/pendant-que-vous-dormiez-kazakhstan-coree-du-nord-tesla-haiti-les-informations-de-la-nuithttps://www.utilitydive.com/news/legacy-auto-brands-chase-Tesla-on-EVs/616623/https://www.shanghaisun.com/news/272101806/rights-groups-urge-tesla-to-close-showroom-in-chinas-xinjianghttp://www.msn.com/de-de/finanzen/top-stories/tesla-wegen-neuen-gesch%C3%A4fts-in-xinjiang-in-der-kritik/ar-AASqL3Dhttps://www.afr.com/companies/mining/how-a-nickel-mine-in-new-caledonia-could-be-the-key-to-tesla-s-success-20220105-p59m0ghttps://www.business-standard.com/article/international/private-sector-should-oppose-chinese-genocide-us-on-tesla-xinjiang-store-122010500204_1.htmlhttps://www.nordkurier.de/nachrichten/ticker/tesla-wegen-neuen-geschaefts-in-xinjiang-in-der-kritik-0546589201.htmlhttps://www.n-tv.de/wirtschaft/Tesla-sorgt-in-USA-fuer-Kritik-article23037088.htmlhttps://www.helmstedter-nachrichten.de/wirtschaft/article234236977/Tesla-wegen-neuen-Geschaefts-in-Xinjiang-in-der-Kritik.htmlhttps://swarajyamag.com/news-brief/elon-musks-tesla-opens-showroom-in-xinjiang-despite-reports-about-uyghur-oppression-in-chinese-regionhttps://www.fm1077.ca/nouvelles/automobile/452861/tesla-a-ete-a-deux-doigts-de-livrer-un-million-de-vehicules-en-2021https://www.tagesschau.de/wirtschaft/tesla-autohaus-xinjiang-uiguren-101.htmlhttps://www.autonews.com/china/tesla-under-fire-opening-showroom-chinas-xinjiang-regionhttps://www.stuttgarter-zeitung.de/inhalt.china-tesla-wegen-neuen-geschaefts-in-xinjiang-in-der-kritik.92d324c4-e0db-4293-bc29-23ea498fc14d.htmlhttps://www.teslarati.com/tesla-giga-nevada-recycled-2170-battery-use/https://www.bgr.in/news/why-americans-are-demanding-elon-musk-to-shutdown-a-tesla-showroom-in-china-1033779/https://lasentinel.net/tesla-odp-rise-applied-therapeutics-newmont-fall.htmlhttps://www.freiepresse.de/nachrichten/wirtschaft/tesla-wegen-neuen-geschaefts-in-xinjiang-in-der-kritik-artikel11918652https://www.europesun.com/news/272102532/private-sector-should-oppose-chinese-genocide-us-on-tesla-opening-showroom-in-xinjianghttps://zeenews.india.com/mobility/analysis-how-tesla-found-ways-around-global-chip-shortage-to-reach-close-to-million-ev-sales-2425435.htmlhttps://www.zazoom.it/2022-01-05/cina-musk-apre-uno-showroom-tesla-nello-xinjiang-e-bufera/10120577/https://www.bignewsnetwork.com/news/272102534/us-based-muslim-civil-liberties-organization-urges-tesla-to-close-showroom-in-xinjianghttps://www.watson.ch/digital/wirtschaft/877347299-tesla-eroeffnet-showroom-in-chinesischer-uiguren-provinz-heftige-kritikhttps://www.wiwo.de/unternehmen/industrie/e-autobauer-tesla-steht-wegen-autohaus-in-chinesischer-provinz-xinjiang-in-der-kritik/27945116.htmlhttps://www.faz.net/aktuell/wirtschaft/unternehmen/kritik-an-tesla-wegen-niederlassung-in-xinjiang-17716240.htmlhttps://trends.knack.be/economie/bedrijven/tesla-opent-showroom-in-centrum-van-chinese-mensenrechtenschendingen/article-news-1819041.htmlhttps://www.msn.com/en-us/autos/news/tesla-model-s-goes-752-miles-with-a-prototype-battery-from-a-michigan-startup/ar-AASryDbhttps://www.newsweek.com/truce-nikola-withdraws-2b-suit-against-tesla-agree-drop-all-claims-against-each-other-1665868
# Fetching (6/50): https://www.capital.fr/auto/cette-batterie-exploserait-lautonomie-de-la-tesla-model-s-1424763https://www.dw.com/en/china-dismisses-tesla-xinjiang-showroom-criticism-as-us-hypocrisy/a-60348544https://www.theepochtimes.com/california-dmv-reviewing-approach-to-regulating-teslas-public-self-driving-test-report_4208619.htmlhttps://cleantechnica.com/2022/01/05/our-next-energy-tests-its-750-mile-range-prototype-in-a-tesla-model-s/https://techxplore.com/news/2022-01-tesla-cameras-only-autonomous-controversy.htmlhttps://interestingengineering.com/a-prototype-battery-pack-powers-tesla-model-s-for-752-miles-on-a-single-chargehttps://www.challenges.fr/economie/tesla-au-xinjiang-pekin-rejette-les-critiques-americaines_795533http://www.thesmokinggun.com/documents/crime/tesla-stock-fraudster-274819https://www.zerohedge.com/markets/tesla-recall-search-trend-erupts-record-highs-amid-quality-control-woeshttps://www.udayavani.com/english-news/indian-origin-ashok-elluswamy-teslas-autopilot-director-was-hired-thru-musks-tweethttps://politika.bg/bg/a/view/tesla-e-kritikuvana-zaradi-otkrivaneto-na-shourum-v-sinczjan-98500https://naslovi.net/2022-01-06/b92/stize-baterija-sa-kojom-tesla-prelazi-1-200-km-u-realnim-uslovima-voznje/29677692https://cleantechnica.com/2022/01/05/coast-to-coast-in-a-tesla-model-y/https://www.ndtv.com/world-news/china-news-tesla-showroom-in-xinjiang-china-hits-back-at-us-over-demands-for-closure-of-tesla-showroom-in-xinjiang-2692559https://www.torquenews.com/11826/nikola-drops-2-billion-patent-suit-against-tesla
# Fetching (7/50): https://www.caribbeanherald.com/news/272119188/record-breaking-year-as-tesla-delivers-nearly-1-million-carshttp://www.elvocerous.com/index.php/features/articles-2/130-reportajes/123440-muere-nikola-tesla-el-fisico-austriaco-cuyo-nombre-honra-los-nuevos-autos-inteligenteshttp://www.thesmokinggun.com/documents/crime/tesla-stock-fraudster-274819https://www.washingtonpost.com/business/on-small-business/covid-fraudster-who-bought-property-tesla-stock-with-stolen-cash-is-caught/2022/01/07/ab080920-6fe8-11ec-b1e2-0539da8f4451_story.htmlhttps://www.bnnbloomberg.ca/covid-fraudster-who-bought-property-tesla-stock-with-stolen-cash-is-caught-1.1704563https://www.alo.rs/razonoda/istorija/583806/nikola-tesla-oto-skorceni-adolf-hitler-misteriozna-smrt/vesthttps://www.elconfidencial.com/tecnologia/novaceno/2022-01-07/volvo-tesla-piloto-automatico-coche-autonomo_3354887/https://www.msn.com/en-us/money/markets/oregon-man-who-defrauded-covid-relief-programs-used-sheer-dumb-luck-to-net-13m-in-tesla-stock-sentenced-to-4-years-in-prison/ar-AASwrtLhttps://www.roadandtrack.com/news/a38694808/tesla-model-s-plaid-track-mode/https://www.austinglobe.com/news/272119188/record-breaking-year-as-tesla-delivers-nearly-1-million-carshttps://hoy.com.do/tesla-pide-cambiar-juicio-de-california-a-texas-por-negatividad-hacia-musk/
# Fetching (8/50): https://www.nbcdfw.com/news/business/money-report/elon-musk-says-tesla-will-raise-price-of-full-self-driving-driver-assistance-to-12000/2854531/https://www.theguardian.com/technology/2022/feb/07/sec-tesla-elon-musk-tweet-subpoenahttps://www.aljazeera.com/economy/2022/2/7/tesla-receives-sec-subpoena-in-ongoing-quarrel-over-musk-tweetshttps://www.malaymail.com/news/money/2022/02/07/tesla-receives-subpoena-from-sec-over-2018-settlement/2040093https://insideevs.com/news/559411/us-tesla-bmw-premium-sales/https://www.businessinsider.in/tech/news/see-how-elon-musks-boring-company-ramped-up-its-las-vegas-hyperloop-to-70-teslas/articleshow/88764675.cmshttps://cleantechnica.com/2022/01/08/tesla-fsd-price-goes-up-to-12000-as-expected/https://www.torquenews.com/14335/tesla-producing-semis-pepsico-4680-batterieshttps://www.dailymail.co.uk/news/article-10485055/Teslas-bitcoin-holdings-worth-nearly-2-bln-filing.htmlhttps://www.nbcsandiego.com/news/business/money-report/elon-musk-says-tesla-will-raise-price-of-full-self-driving-driver-assistance-to-12000/2833962/https://www.nbcconnecticut.com/news/business/money-report/elon-musk-says-tesla-will-raise-price-of-full-self-driving-driver-assistance-to-12000/2686947/https://www.autoblog.com/2022/01/08/tesla-supply-chain/https://www.msn.com/en-us/money/personalfinance/covid-loans-paid-for-tesla-shares-and-25-properties-in-oregon-and-california-feds-say/ar-AASy6iChttps://www.marketscreener.com/quote/stock/TESLA-INC-6344549/news/Tesla-receives-subpoena-from-SEC-over-2018-settlement-37801579/https://www.newdelhitimes.com/rights-groups-urge-tesla-to-close-showroom-in-chinas-xinjiang/https://www.newyorktelegraph.com/news/272125539/ev-charging-stations-market-is-going-to-boom--abb-aerovironment-chargepoint-engie-teslahttps://www.nbclosangeles.com/news/business/money-report/elon-musk-says-tesla-will-raise-price-of-full-self-driving-driver-assistance-to-12000/2793505/https://www.nbcphiladelphia.com/news/business/money-report/elon-musk-says-tesla-will-raise-price-of-full-self-driving-driver-assistance-to-12000/3100927/
# Fetching (9/50): https://www.tecmundo.com.br/mobilidade-urbana-smart-cities/231637-nikola-corp-desiste-processo-r-11-bilhoes-tesla.htmhttps://www.wiredprnews.com/tesla-receives-sec-subpoena-in-ongoing-quarrel-over-musk-tweets-automotive-industry-news/https://www.investor.bg/a/566-novini-i-analizi/367141-mask-iska-da-izmesti-myastoto-na-gledane-na-deloto-mu-za-tuitovete-svarzani-s-teslahttps://www.watoday.com.au/business/companies/why-tesla-soared-as-other-automakers-struggled-to-make-cars-20220109-p59muq.htmlhttp://ecolounge.hu/zoldmotor/gepek-gyartjak-majd-a-gepeket-a-tesla-kovetkezo-gyarabanhttps://www.dailymail.co.uk/news/article-10383579/TV-historian-Dan-Jones-says-intruder-breaking-Tesla-using-watch-Netflix.htmlhttps://katcountry989.com/2022/02/08/after-months-of-complaint-by-elon-musk-biden-acknowledges-tesla/https://www.theage.com.au/world/oceania/musk-turns-to-new-caledonia-to-power-tesla-s-ambitions-away-from-china-20211231-p59l1v.htmlhttps://www.nbcbayarea.com/news/business/money-report/this-tesla-owner-says-he-mines-up-to-800-a-month-in-cryptocurrency-with-his-car/2773656/https://www.thestar.com.my/business/business-news/2022/02/08/tesla-receives-subpoena-from-us-securities-regulator-over-2018-settlementhttps://www.rte.ie/lifestyle/motors/2022/0109/1272667-modified-tesla-achieves-1200-kilometre-range-on-one-charge/https://www.news24.com/fin24/companies/tesla-receives-subpoena-from-us-securities-regulator-over-2018-settlement-20220208
# Fetching (10/50): https://www.drive.com.au/news/tesla-hikes-price-for-full-self-driving-tech/https://www.yumasun.com/opinion/guest-editorial-tesla-in-china-a-bad-turn-for-u-s-company/article_a472eb54-6ff0-11ec-91c6-bf25b1346379.htmlhttps://tribune.com.pk/story/2342731/biden-finally-acknowledges-the-role-of-tesla-in-ev-manufacturinghttps://www.nevadacurrent.com/2022/01/10/what-ccsd-teslaandgrocerystores-have-in-common-both-employ-a-lot-of-medicaid-recipients/https://www.gizmodo.com.au/2022/01/a-michigan-startup-retrofitted-a-tesla-model-s-with-a-battery-that-more-than-doubles-its-range/https://energy.einnews.com/pr_news/560157445/electric-vehicle-charging-points-market-2030-abb-chargepoint-city-of-amsterdam-greenflux-ionity-shell-tesla-vincihttp://www.msn.com/en-us/autos/news/watch-tesla-fsd-cause-an-eight-car-pile-up-the-same-day-musk-made-it-available-to-everyone/ar-AA16bvuthttps://www.finanznachrichten.de/nachrichten-2022-01/54936664-talon-metals-corp-tesla-and-talon-metals-enter-into-supply-agreement-for-nickel-296.htmhttps://www.autonews.com/automakers-suppliers/after-teslas-elon-musk-complained-months-president-biden-acknowledgeshttps://www.teslarati.com/tesla-semi-mobile-megacharger-giga-nevada-photos/https://www.thestranger.com/slog/2022/01/10/64773043/slog-am-kicking-off-the-legislative-session-with-covid-snoqualmie-pass-reopens-and-teslas-now-feature-an-assertive-mode
# Fetching (11/50): https://www.torquenews.com/1083/26-months-after-2019-unveiling-tesla-cybertruck-it-indefinitely-delayedhttps://mix108.com/proposed-nickel-mine-near-duluth-signs-huge-deal-with-tesla/https://www.techtimes.com/articles/271671/20220210/tesla-sued-dfeh-over-unfair-workplace-treatment-employees.htmhttps://www.phonandroid.com/tesla-mobilise-ses-fans-pour-avoir-le-droit-de-vendre-plus-de-voitures-a-new-york.htmlhttps://www.teslarati.com/tesla-model-x-plaid-7-seats-ccs2-walkthrough/https://www.bgr.in/news/this-man-is-using-his-tesla-to-earn-up-to-rs-60000-a-month-in-cryptos-heres-how-1035085/https://www.bursa.com/haber/bakan-varank-teslanin-turkiye-pazarina-girmek-istedigini-acikladi-567766.htmlhttps://noticias.uol.com.br/ultimas-noticias/afp/2022/02/10/california-acusa-tesla-de-segregacao-racial-em-fabrica.htmhttps://austin.culturemap.com/news/innovation/01-11-22-tesla-vehicle-production-new-austin-factory/https://motorillustrated.com/next-generation-tesla-model-s-unveiled/92829/https://www.turkiyegazetesi.com.tr/t-otomobil/bakan-varank-duyurdu-abdli-otomobil-devi-tesla-turkiye-pazarina-giriyor-941251http://www.econotimes.com/Tesla-announces-recall-for-26681-vehicles-in-the-US-1626831https://www.autoevolution.com/news/tesla-vice-president-of-people-leaves-the-company-to-join-career-network-firm-178821.htmlhttp://www.businessnorth.com/around_the_region/tesla-talon-metals-enter-into-nickel-supply-agreement/article_adca9826-731c-11ec-9e72-e33b48a6fd99.htmlhttps://3dnews.ru/1057716/eshchyo-do-zapuska-predpriyatiya-v-germanii-tesla-poluchit-pravo-vipustit-na-nyom-bolee-dvuh-tisyach-kuzovov-dlya-model-y
# Fetching (12/50): https://www.correiobraziliense.com.br/mundo/2022/02/4984298-california-acusa-tesla-de-segregacao-racial-em-fabrica.htmlhttps://www.msn.com/en-us/news/technology/dmv-revisiting-its-approach-to-regulating-teslas-public-self-driving-test/ar-AASGd21https://insideevs.com/news/560269/automakers-follow-tesla-electric-cars/https://www.msn.com/en-us/news/technology/california-dmv-to-review-tesla-s-full-self-driving-and-other-technology-to-determine-software-s-future-use/ar-AASGocYhttps://www.fxstreet.com/news/tsla-stock-price-and-forecast-tesla-ramps-up-china-deliveries-202201121132https://www.leblogauto.com/2022/01/tesla-autorise-a-produire-2-000-model-y-a-berlin-a-vendre.htmlhttps://www.torquenews.com/11826/tesla-china-sets-another-production-record-december-following-2-months-growth-stabilizationhttps://froggyweb.com/2022/01/11/nickel-mine-developer-has-major-commitment-from-tesla/https://insideevs.com/news/560362/dmv-tesla-fsd-data-sharing/https://www.torquenews.com/14335/tesla-semi-spotted-san-francisco-bridgehttps://www.biofuelsdigest.com/bdigest/2022/01/12/the-bioeconomy-jump-to-light-speed-10-storylines-shaking-the-world-exxon-j-m-klm-ugi-amyris-tesla-origin-more/http://thepeninsulaqatar.com/article/12/01/2022/california-reviews-whether-teslas-self-driving-tests-require-regulatory-oversight-1https://www.mesabitribune.com/news/regional/tesla-talon-metals-enter-nickel-supply-deal/article_2998355a-7343-11ec-9d4f-fffd5260fd48.htmlhttps://www.msn.com/en-us/autos/news/automakers-take-yet-another-page-from-teslas-playbook/ar-AASHnkZhttps://www.latimes.com/business/story/2022-01-11/dmv-message-to-legislatures-ontesla-full-self-driving-safety-its-not-our-jobhttps://www.foxbusiness.com/energy/tesla-elon-musk-california-solar-taxhttps://www.perfil.com/noticias/bloomberg/bc-adolescente-afirma-poder-hackear-25-autos-tesla-en-todo-el-mundo.phtmlhttp://www.msn.com/en-us/news/politics/california-dmv-reviewing-tesla-s-assisted-driving-tech/ar-AASI7Vchttps://www.nytimes.com/2022/02/10/technology/tesla-racial-discrimination-california-suit.htmlhttps://www.msn.com/en-us/news/technology/teen-security-researcher-claims-he-can-remotely-access-25-teslas-around-the-globe/ar-AASHU61https://www.autoworldnews.com/articles/39886/20220112/shakeup-tesla-companys-top-black-executive-steps-down-hr-chief.htmhttps://forte.delfi.ee/artikkel/95623703/ratsa-rikkaks-teslaga-usa-hakker-vaidab-et-kaevandab-oma-autoga-kruptovaluutat-800-dollari-eest-kuus
# /tmp/ipython-input-3759818938.py:21: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(html, "html.parser")
# Fetching (13/50): http://www.itechpost.com/articles/108675/20220113/tesla-russia-coming-soon-elon-musk-reacts-owners-office-request.htmhttps://dallas.culturemap.com/news/innovation/01-12-22-tesla-vehicle-production-new-austin-factory/https://www.reflector.com/opinion/editorial_columnists/editorial-selling-in-china-a-bad-turn-for-tesla/article_26247f5f-72f6-5405-bd05-c200a9b9cc48.htmlhttps://news.yahoo.com/tesla-slashes-prices-20-broad-110102075.htmlhttps://www.torquenews.com/15475/elon-musk-update-about-tesla-cybertruck-semi-roadster-q4-earnings-call-january-26thhttps://wsau.com/2022/01/13/court-rejects-tesla-push-to-reinstate-higher-u-s-fuel-economy-penalties/https://menafn.com/1103532791/Teslas-plan-to-sell-cars-in-India-facing-hurdles&source=25https://www.latimes.com/business/story/2023-01-13/tesla-slashes-prices-boost-saleshttps://www.theguardian.com/technology/2022/jan/13/california-reviews-tesla-self-driving-tests-require-oversighthttps://www.autoblog.com/2023/01/13/tesla-discounts-models-globally/https://insideevs.com/news/560556/tesla-gigafactory-austin-giga-press/https://www.techtimes.com/articles/270454/20220112/tesla-protests-against-california-s-solar-tax-backed-gov-newsom.htmhttps://europe.autonews.com/automakers/teslas-self-driving-tests-might-require-regulatory-oversight-califhttps://www.techtimes.com/articles/270481/20220113/cybertruck-delayed-tesla-2022-promise-removed-from-website.htmhttps://www.dailymail.co.uk/sciencetech/article-10398845/Tesla-removes-promise-2022-production-maligned-Cybertruck-website.htmlhttps://oilprice.com/Latest-Energy-News/World-News/19-Year-Old-Hacks-into-25-Teslas-Simultaneously.htmlhttps://www.msn.com/en-us/money/other/california-warns-of-possible-oversight-of-tesla-tests/ar-AASIAWVhttps://www.teslarati.com/volkswagen-2021-ev-sales-96-percent-increase/
# Fetching (14/50): https://www.msn.com/en-us/autos/news/so-much-for-the-tesla-cybertruck-this-year-report/ar-AASMzz8https://techstory.in/california-regulator-revisiting-teslas-full-self-driving-beta-software/https://www.foxbusiness.com/markets/elon-musk-tesla-dogecoin-merchandisehttps://menafn.com/1103537899/Sri-Lanka-US-based-Muslim-civil-liberties-organization-urges-Tesla-to-close-showroom-in-Xinjiang&source=22https://www.theepochtimes.com/elon-musk-says-tesla-accepting-dogecoin-payments-for-some-merchandise-cryptocurrency-surges_4213058.htmlhttps://www.fox7austin.com/news/local-organization-hopes-graduates-will-help-fill-tesla-samsung-jobshttps://3dnews.ru/1057975/tesla-perenesla-nachalo-proizvodstva-pikapa-cybertruck-na-2023-goda-izza-konkurentovhttps://www.msn.com/en-us/money/other/canada-opens-probe-into-teslas-heating-system-following-consumer-complaints/ar-AASLicbhttps://menafn.com/1103538486/Tesla-to-accept-dogecoin-as-payment-for-merchandise-says-Musk&source=26https://www.ecrater.com/p/40501475/the-autobiography-of-nikola-tesla-and-otherhttps://www.msn.com/en-us/autos/news/dogecoin-jumps-9-after-elon-musk-says-its-can-be-used-buy-tesla-merchandise/ar-AASMdyShttp://www.itechpost.com/articles/108696/20220113/tesla-cybertruck-release-date-update-sparks-major-concerns-coming-2022.htmhttps://www.ktvu.com/news/tesla-fights-californias-proposed-solar-taxhttps://www.finanznachrichten.de/nachrichten-2022-01/54981797-dogecoin-jumps-after-elon-musk-tweets-it-can-be-used-to-buy-tesla-merchandise-020.htmhttps://www.itbusiness.ca/news/hashtag-trending-jan-14-buying-property-in-the-metaverse-right-to-repair-for-cars-reselling-teslas-cyberquad/120392https://www.techtimes.com/articles/270475/20220113/tesla-announce-new-product-roadmap-update-january-26-see-semi.htmhttps://www.zonebourse.com/cours/action/TESLA-INC-6344549/actualite/Tesla-repousse-la-production-initiale-du-Cybertruck-a-debut-2023-37544100/https://www.msn.com/en-us/news/technology/tesla-now-lets-you-buy-some-merch-in-dogecoin/ar-AASLLuRhttps://www.torquenews.com/15475/tesla-giga-berlin-gets-german-federal-government-support-start-productionhttps://www.southbendtribune.com/story/news/local/2022/01/14/tesla-electric-car-showroom-mishawaka-appears-dead/9185951002/https://houston.culturemap.com/news/innovation/01-14-22-tesla-megapacks-angleton-texas-ercot/http://www.msn.com/de-de/auto/nachrichten/muss-tesla-auch-in-deutschland-defekte-autos-zur%C3%BCckrufen-kraftfahrtbundesamt-setzt-dem-e-autobauer-ein-ultimatum/ar-AASMC8Nhttps://www.theepochtimes.com/court-rejects-tesla-push-to-reinstate-higher-us-fuel-economy-penalties_4211407.htmlhttps://insideevs.com/news/560766/tesla-cybertruck-production-delayed-2023/
# Fetching (15/50): https://www.autoblog.com/2022/01/15/tesla-heating-safety-issue-nhtsa/https://wsau.com/2022/01/14/nhtsa-evaluating-potential-safety-concerns-related-to-heating-issue-of-tesla-cars/https://cleantechnica.com/2022/01/14/frozen-front-flap-leads-to-cold-cabins-for-teslas-with-heat-pumps/https://cleantechnica.com/2022/01/15/whats-the-latest-with-teslas-cybertruck/https://3dnews.ru/1058068/amerikanskie-regulyatori-toge-v-kurse-problem-s-teplovimi-nasosami-elektromobiley-tesla
# Fetching (16/50): https://www.ceskenoviny.cz/zpravy/tesla-bude-ziskavat-grafit-do-baterii-i-z-mosambiku-snizi-zavislost-na-cine/2146507https://techncruncher.blogspot.com/2022/01/tesla-asked-law-firm-to-fire-attorney.htmlhttps://buffalonews.com/lifestyles/technology/tesla-inks-deal-to-get-key-battery-component-outside-china/article_e57f31c5-8f2c-5637-81c7-db4fa7688371.htmlhttps://www.foxbusiness.com/economy/elon-musks-tesla-law-firm-fire-associate-sechttps://carbuzz.com/news/tesla-has-a-new-problem-in-californiahttps://www.forbes.com/sites/jeffkart/2022/01/16/michigan-startups-gemini-battery-powers-tesla-for-752-miles-on-a-single-charge/
# Fetching (17/50): https://www.team-bhp.com/news/tesla-model-s-prototype-battery-offers-1419-km-rangehttps://europe.autonews.com/automakers/tesla-gaining-bmw-us-luxury-sales-crownhttps://www.teslarati.com/tesla-battery-graphite-deal-au-mozambique-mine/https://techcrunch.com/2022/01/17/the-station-cali-regulators-eye-tesla-fsd-turo-files-to-go-public-local-motors-shuts-down/http://www.msn.com/en-us/news/technology/elon-musk-faces-trial-over-his-2018-plan-to-take-tesla-private/ar-AA16qhZMhttps://insideevs.com/news/561324/tesla-modely-potential-structural-pack/https://www.autoforum.cz/zajimavosti/tesla-se-prekonava-zene-dodala-nove-auto-bez-brzdove-desky-nejlepsi-je-ovsem-reakce-techniku/https://www.drive.com.au/news/2023-tesla-cybertruck-to-spawn-toyota-hilux-rival-report/https://www.nytimes.com/2023/01/17/business/elon-musk-tesla-trial-funding-secured.html
# Fetching (18/50): https://actualidad.rt.com/actualidad/417201-tesla-revolucionaria-bateria-recorre-1200-cargahttps://www.ladbible.com/news/tesla-battery-life-20220118https://www.oann.com/tesla-investors-urge-judge-to-order-musk-repay-13-billion-for-solarcity-deal/https://gmauthority.com/blog/2022/01/tesla-cybertruck-delayed-until-early-2023/https://techcrunch.com/2022/01/18/tesla-shareholders-urge-judge-to-find-musk-coerced-board-to-buy-solarcity/https://www.wtkr.com/news/national/felony-charges-filed-in-fatal-crash-involving-a-tesla-on-autopilot-are-1sthttps://economictimes.indiatimes.com/tech/startups/ola-electric-takes-tesla-route-to-build-a-twitter-community/articleshow/88962520.cmshttps://www.bnnbloomberg.ca/musk-engineered-solarcity-purchase-as-a-bailout-tesla-investors-argue-1.1709246https://www.marketscreener.com/business-leaders/Elon-Musk-1364/news/Tesla-investors-urge-judge-to-order-Musk-repay-13-billion-for-SolarCity-deal--37577966/https://www.msn.com/en-us/autos/news/in-a-first-a-tesla-driver-is-facing-felony-charges-for-a-fatal-autopilot-crash/ar-AASUx0ohttp://www.msn.com/en-us/news/technology/a-tech-founder-took-out-a-full-page-ad-in-the-new-york-times-to-accuse-tesla-of-treating-full-self-driving-users-like-crash-test-dummies/ar-AASU5IL
# Fetching (19/50): https://economictimes.indiatimes.com/industry/renewables/tesla-investors-urge-judge-to-make-musk-repay-13b-for-solarcity-deal/articleshow/88984858.cmshttps://ummid.com/news/2022/january/19.01.2022/in-a-first-criminal-charge-against-tesla-owner-for-autopilot-crash-in-us.htmlhttp://www.msn.com/de-de/finanzen/top-stories/nach-unfall-mit-eingeschaltetem-tesla-autopilot-mann-wegen-zweifachen-totschlags-vor-gericht/ar-AASVQX8https://zeenews.india.com/electric-vehicles/tesla-s-12000-full-self-driving-fsd-slammed-called-worst-software-by-advocacy-group-2429021.htmlhttp://topnews.net.nz/content/21-tesla-roadster-and-model-3-emerge-most-anticipated-and-most-desirable-evshttps://www.autoworldnews.com/articles/39902/20220118/tesla-turns-mozambique-graphite-looks-reduce-dependence-china-car-batteries.htmhttps://www.insideedition.com/tesla-driver-charged-with-manslaughter-in-fatal-crash-involving-autopilot-72661https://tsn.ua/auto/news/avto_mir/u-ssha-vpershe-v-istoriyi-visunuli-zvinuvannya-vodiyu-tesla-cherez-smertelnu-dtp-na-avtopiloti-1957000.htmlhttps://tech.24tv.ua/vpershe-ssha-vodiy-tesla-postane-pered-sudom-novini-tehnologiy_n1845823https://markets.businessinsider.com/news/stocks/la-court-files-lawsuit-against-2019-tesla-that-killed-2-1031114198https://www.msn.com/en-us/money/other/tesla-driver-in-fatal-california-crash-first-to-face-felony-charges-involving-autopilot/ar-AASVr0Yhttps://www.wkbw.com/news/national/felony-charges-filed-in-fatal-crash-involving-a-tesla-on-autopilot-are-1st
# Fetching (20/50): https://carbuzz.com/news/gms-plan-for-ev-charging-should-put-tesla-on-noticehttps://www.techspot.com/news/93058-elon-musk-responds-tragic-ad-slamming-tesla-full.htmlhttps://gmauthority.com/blog/2022/01/tesla-cybertruck-delayed-until-early-2023/comment-page-2/https://www.bignewsnetwork.com/news/272211328/to-bypass-china-tesla-to-buy-battery-minerals-from-mozambiquehttps://www.bnnbloomberg.ca/truecar-founder-s-new-venture-will-get-you-a-tesla-in-10-minutes-1.1710795https://www.prnewswire.com/news-releases/autoweb-to-offer-its-car-shopping-audience-a-flexible-affordable-way-to-subscribe-to-a-tesla-model-3-with-autonomy-301465273.htmlhttps://usa.inquirer.net/91685/autopilot-tesla-car-has-killed-two-people-in-california-whos-guiltyhttps://www.autoevolution.com/news/tesla-worker-dies-in-powertrain-assembly-line-in-fremont-179607.htmlhttps://www.latimes.com/espanol/california/articulo/2022-01-20/un-tesla-con-piloto-automatico-mato-a-dos-personas-en-gardena-es-el-conductor-culpable-de-homicidio-involuntariohttps://www.tribunnews.com/otomotif/2022/01/20/fitur-autopilot-picu-kecelakan-fatal-pengemudi-mobil-tesla-diincar-pasal-pembunuhanhttps://insideevs.com/news/562032/tesla-giga-berlin-100-modely/https://www.washingtonpost.com/technology/2022/01/20/tesla-autopilot-charges/https://tcbmag.com/what-a-tesla-deal-might-mean-for-the-tamarack-mining-project-in-northern-minnesota/https://www.forbes.com/sites/zacharysmith/2022/01/20/house-lawmakers-are-latest-to-criticize-tesla-for-opening-showroom-in-chinas-xinjiang-region/https://www.saltlakecitysun.com/news/272211328/tesla-looks-to-mozambique-to-replace-china-for-mineralshttps://www.bnnbloomberg.ca/tesla-judge-says-137-million-racism-verdict-is-extremely-high-1.1710232http://www.msn.com/de-de/finanzen/top-stories/nach-unfall-mit-eingeschaltetem-tesla-autopilot-mann-wegen-zweifachen-totschlags-vor-gericht/ar-AASXzGthttps://www.tecnoandroid.it/2022/01/20/conducente-tesla-prima-volta-accusato-dopo-incidente-1021294
# Fetching (21/50): https://cleantechnica.com/2022/01/21/tesla-insurance-expands-to-arizona-ohio/https://www.businessinsider.com.au/employee-died-tesla-factory-hub-fremont-california-2022-1https://www.forbes.com/sites/roslynlayton/2022/01/28/the-grain-of-truth-in-the-critique-of-musk-tesla-and-full-self-driving-fsd/https://hvg.hu/kkv/20220121_Mit_keres_a_Tesla_az_ujgurok_foldjenhttps://www.marketwatch.com/story/hollywood-indie-film-distributor-admits-stealing-30-million-from-blackrock-to-buy-a-14-million-beverly-hills-mansion-and-a-tesla-11642776000https://www.zerohedge.com/markets/tesla-shareholders-seek-13-billion-repayment-solar-city-bailouthttps://www.theepochtimes.com/us-lawmakers-call-tesla-expansion-in-xinjiang-misguided_4226077.htmlhttps://www.msn.com/en-us/money/companies/hollywood-indie-film-distributor-admits-stealing-30-million-from-blackrock-to-buy-a-14-million-beverly-hills-mansion-and-a-tesla/ar-AAT0JiAhttps://www.onenewspage.com/n/Business/1zpjux7yyi/Elon-Musk-takes-witness-stand-to-defend-Tesla.htm
# Fetching (22/50): https://www.theepochtimes.com/tesla-workers-death-at-fremont-factory-being-probed-report_4227470.htmlhttps://www.techtimes.com/articles/270887/20220121/tesla-gigafactory-texas-deliver-model-y-evs-quarter-giga-berlin.htmhttp://www.msn.com/de-de/finanzen/top-stories/tesla-ein-mitarbeiter-ist-in-der-fremont-gigafactory-gestorben/ar-AAT2zyhhttps://www.techtimes.com/articles/270885/20220121/tesla-xinjiang-expansion-criticized-lawmakers%E2%80%94saying-move-powers-chinese-government.htmhttps://www.ledauphine.com/magazine-automobile/2022/01/22/savez-vous-pourquoi-la-premiere-tesla-n-etait-pas-une-tesla
# Fetching (23/50): https://greekreporter.com/2022/01/23/electric-car-produced-greece-decades-before-elon-musk-tesla/https://www.republika.co.id/berita/r65cbp368/kecelakaan-pengemudi-tesla-di-kalifornia-dikenai-tuduhan-pembunuhanhttps://www.businessinsider.com/elon-musk-tesla-china-xinjiang-uyghurs-dark-future-2022-1
# Fetching (24/50): https://www.msn.com/en-us/autos/news/tesla-s-factory-makes-more-cars-than-any-other-american-plant/ar-AAT5IXmhttps://www.autoworldnews.com/articles/39924/20220124/another-death-rocks-tesla-employee-dies-working-companys-fremont-factory.htmhttps://www.electrive.com/2022/01/24/tesla-subscription-service-autonomy-launches-in-california/https://carbuzz.com/news/tesla-chargers-for-non-tesla-vehicles-may-be-here-sooner-than-you-thinkhttps://www.carscoops.com/2022/01/gm-plans-to-introduce-tesla-style-behavior-based-insurance-product/https://www.capital.fr/entreprises-marches/tesla-pourrait-bientot-vendre-de-nouveaux-appareils-surprenants-1426367https://www.933thedrive.com/2022/01/24/tesla-countersues-jpmorgan-over-contract-affected-by-musk-tweet/https://investir.lesechos.fr/actions/actualites/tesla-poursuit-jpmorgan-au-sujet-d-un-contrat-affecte-par-un-tweet-de-musk-1999412.php
# Fetching (25/50): https://www.capital.fr/auto/tesla-contre-attaque-et-accuse-jpmorgan-de-mauvaise-foi-et-davarice-1426515https://cleantechnica.com/2022/01/25/tesla-semi-megachargers-fully-installed-at-giga-nevada/https://www.autoworldnews.com/articles/39940/20220125/panasonic-mass-produce-tesla-4680-battery-cells-2023-will-reportedly.htmhttps://www.businessinsider.com.au/tesla-biden-elon-musk-petition-electric-cars-2022-2https://qz.com/india/2116260/when-will-tesla-start-selling-in-india/https://insideevs.com/news/563047/tesla-countersuit-jp-morgan/https://www.zonebourse.com/barons-bourse/Elon-Musk-1364/actualites/Tesla-poursuit-JPMorgan-au-sujet-d-un-contrat-affecte-par-un-tweet-de-Musk--37627927/https://austin.culturemap.com/news/real-estate/01-25-22-mirador-master-planned-community-near-austin-tesla-factory/https://www.ksl.com/article/50334404/injured-draper-man-now-faces-charges-2-years-after-fiery-fatal-tesla-crashhttps://www.businessgreen.com/news/4043823/reports-panasonic-start-supplying-gen-batteries-tesla-2023https://www.engadget.com/the-morning-after-panasonics-higher-capacity-tesla-battery-could-appear-next-year-121502013.htmlhttps://www.carscoops.com/2023/01/tesla-will-spend-3-6-billion-expanding-nevada-gigafactory-to-produce-the-semi/https://katcountry989.com/2022/01/25/ford-aims-to-be-the-tesla-of-connected-commercial-vehicles/https://www.teslarati.com/spacex-cargo-dragon-crs-24-successful-recovery/https://www.imore.com/apple-wallet-now-accepts-tesla-insurance-cardshttps://www.msn.com/en-us/money/companies/gms-7-billion-investment-intensifies-ev-battle-with-ford-tesla/ar-AAT87hvhttps://cleantechnica.com/2022/01/25/gm-follows-teslas-lead-with-algorithm-based-insurance/https://www.oann.com/ford-aims-to-be-the-tesla-of-connected-commercial-vehicles/https://www.drive.com.au/news/updated-2023-tesla-cybertruck-leaked-in-full/https://www.msn.com/en-us/autos/news/tesla-still-has-it-all-to-do/ar-AAT7SpHhttps://www.msn.com/en-us/autos/news/an-employee-died-wednesday-at-teslas-factory-hub-in-fremont-california/ar-AASZgjJhttps://3dnews.ru/1058641/svegaya-versiya-prototipa-tesla-cybertruck-podtverdila-otsutstvie-dvernih-ruchekhttps://interestingengineering.com/tesla-signed-deal-for-the-first-us-nickel-supply-for-battery-production
# Fetching (26/50): https://www.investor.bg/novini/444/a/shefyt-na-ford-iskame-da-sme-kato-tesla-v-segmenta-na-tyrgovskite-avtomobili-344507/https://www.stltoday.com/business/local/gms-7-billion-investment-intensifies-ev-battle-with-ford-tesla/article_112dc44b-a86d-546d-a5d2-6758baa63423.htmlhttps://www.bnnbloomberg.ca/the-lawyer-suing-tesla-for-racism-at-its-california-plant-and-winning-1.1713600https://www.techtimes.com/articles/271006/20220125/tesla-owners-now-link-car-insurance-directly-apple-wallet.htmhttps://www.kauppalehti.fi/uutiset/tesla-varoitti-toimitusketjujen-hairioiden-jatkumisesta-osake-kaantyi-lopulta-nousuun-jalkikaupankaynnissa/27c407af-9e2b-4cd8-94be-678db87c3d92https://www.techtimes.com/articles/271070/20220126/tesla-bot-become-powerful-ai-development-platform-kaparthy-now-looks.htmhttps://www.tribunnews.com/new-economy/2022/01/26/investasi-66-miliar-dolar-as-untuk-pabrik-mobil-listrik-general-motors-siap-ungguli-teslahttps://www.msn.com/en-us/money/companies/tesla-reports-record-profit/ar-AATaU1ghttps://www.theepochtimes.com/ford-aims-to-be-the-tesla-of-connected-commercial-vehicles_4238190.htmlhttps://www.autoworldnews.com/articles/39945/20220126/tesla-vs-general-motors-gm-plans-beat-elon-musks-electric.htmhttps://www.manager.bg/avtomobili/gm-investira-66-mrld-dolara-v-opit-da-detronira-teslahttps://www.bnnbloomberg.ca/five-things-to-watch-and-listen-for-when-tesla-reports-earnings-1.1713439https://www.wionews.com/world/us-auto-safety-regulators-seek-more-information-from-tesla-in-drive-game-probe-447613https://www.caribbeanherald.com/news/272234096/us-car-giant-reveals-plan-to-dethrone-teslahttps://tech.24tv.ua/ru/avtomobilnom-zavode-tesla-skonchalsja-rabotnik-novosti-tehnologij_n1851530https://www.latribune.fr/entreprises-finance/banques-finance/industrie-financiere/achat-d-obligations-tesla-et-jpmorgan-s-affrontent-devant-la-justice-902742.html
# Fetching (27/50): https://insideevs.com/news/563533/tesla-production-sites-assignment-january2022/https://www.shacknews.com/article/128515/elon-musk-says-tesla-is-not-currently-working-on-a-25000-carhttps://www.geo.tv/latest/395517-musks-bets-on-tesla-no-human-drivers-this-year-robots-nexthttps://www.autoworldnews.com/articles/39951/20220127/tesla-posts-record-profits-2021-ceo-elon-musk-warns-continued.htmhttps://insideevs.com/news/563435/tesla-giga-texas-modely-4680structural/https://economictimes.indiatimes.com/magazines/panache/elon-musks-bets-on-tesla-says-most-important-products-in-2022-not-cars-but-software-that-drives-them-autonomously-robots-next/articleshow/89156871.cmshttp://markets.businessinsider.com/news/stocks/elon-musk-calls-biden-sock-puppet-omits-tesla-ev-discussion-2022-1https://www.manager.bg/avtomobili/tesla-ochakva-50-rst-na-prodazhbite-prez-tazi-godinahttp://www.msn.com/en-us/autos/news/tesla-s-elon-musk-outlines-ambitious-future-but-no-new-models-this-year/ar-AATbdSuhttps://www.afr.com/companies/manufacturing/production-not-new-products-will-drive-tesla-share-price-20220127-p59rrnhttps://www.techtimes.com/articles/271080/20220126/tesla-cybertruck-prototype-available-giga-texas-production-already-done.htmhttps://www.msn.com/en-us/autos/news/tesla-is-the-new-luxury-king-of-america/ar-AATcMQEhttps://www.msn.com/en-us/money/companies/musks-bets-on-tesla-no-human-drivers-this-year-robots-next/ar-AATcf1Lhttps://www.moneyweb.co.za/news/tech/tesla-beats-on-profit-but-no-cybertruck-new-vehicles-this-year/https://hypebeast.com/2022/1/tesla-q4-2021-earnings-cybertruck-delay-no-new-car-modelshttps://www.kauppalehti.fi/uutiset/tesla-varoittaa-toimitusketjujen-hairioiden-jatkumisesta-osake-kaantyi-lopulta-nousuun-jalkikaupankaynnissa/27c407af-9e2b-4cd8-94be-678db87c3d92https://mowmag.com/attualita/dopo-averci-fatto-entrare-nelle-tesla-ora-musk-ci-vuole-entrare-nella-testahttps://www.thestreet.com/investing/new-tesla-factory-on-the-way-musk-sayshttps://www.wicz.com/story/45731445/tesla-reports-record-profit-but-warns-of-continued-supply-chain-issueshttps://www.newsweek.com/tesla-optimus-robot-human-explained-elon-musk-earnings-call-2022-prototype-1673466
# Fetching (28/50): https://www.business-standard.com/article/international/tesla-s-drop-wipes-out-100-billion-of-market-capitalisation-in-a-day-122012802004_1.htmlhttps://insideevs.com/news/563883/biden-ignores-tesla-musk-responds/https://paultan.org/2018/08/21/tesla-could-build-cheaper-us25000-car-in-three-years/https://www.torquenews.com/15475/giga-texas-model-y-structural-batteries-and-4680-cells-confirmed-teslahttps://www.businessinsider.com/dan-crenshaw-stocks-texas-tesla-rivian-investments-2022-1https://www.forbes.com/sites/roslynlayton/2022/01/28/the-grain-of-truth-in-the-critique-of-musk-tesla-and-full-self-driving-fsd/https://news.finance.ua/ru/news/-/507814/19-letnij-haker-trebuet-ot-ilona-maska-million-dollarov-i-tesla-v-podarokhttps://www.newsweek.com/elon-musk-tweets-vote-them-out-slamming-joe-biden-sock-puppet-tesla-1673827https://techstory.in/musk-calls-biden-a-damp-sock-puppet-in-human-form-after-the-president-highlighted-ev-production-by-gm-and-ford-but-not-tesla/https://www.thedetroitbureau.com/2022/01/tesla-came-out-on-top-for-the-luxury-sales-crown/https://www.techtimes.com/articles/271094/20220127/elon-musk-calls-2021-breakthrough-year-tesla-q4-yields-2.htmhttps://www.energy-storage.news/tesla-deployed-nearly-4gwh-of-energy-storage-in-2021/https://www.businessinsider.com.au/elon-musk-calls-biden-sock-puppet-omits-tesla-ev-discussion-2022-1https://www.ndtv.com/world-news/joe-biden-is-treating-americans-like-fools-tesla-ceo-elon-musk-2734358https://www.latimes.com/business/story/2023-01-27/musk-sec-probe-tesla-self-driving-claimshttps://www.businesstoday.in/auto/story/elon-musks-future-plans-for-tesla-humanoid-robots-self-driving-cars-320620-2022-01-28https://www.islam21c.com/news-views/tesla-shocked-as-demonstrators-take-to-westfield-to-condemn-xinjiang-showroom/https://www.newsit.gr/auto/Tesla-ksekina-prosektika-to-2022-me-tin-eksairetiki-persini-xronia/3456434/https://cleantechnica.com/2022/01/27/ford-general-motors-boast-about-leading-ev-industry-tesla-actually-leads-it/https://www.kbb.com/car-news/tesla-is-americas-best-selling-luxury-automaker/https://www.punto-informatico.it/bitcoin-tesla-elon-musk-crollo-criptovalute/
# Fetching (29/50): https://banksnews.gr/musk-and-biden-feud-all-of-the-tesla-ceos-fights-with-the-us-president/https://insideevs.com/news/563996/tesla-beats-chip-shortage-software/https://www.floridastatesman.com/news/272242278/musk-predicts-50-growth-in-tesla-sales-in-2022https://cleantechnica.com/2022/01/28/tesla-will-support-fsd-licensing-for-other-manufacturers/https://www.leprogres.fr/magazine-automobile/2022/01/29/saviez-vous-que-la-premiere-tesla-n-en-etait-pas-unehttps://www.autoevolution.com/news/canoo-may-be-making-the-same-errors-aptera-and-tesla-made-180317.htmlhttps://www.unionleader.com/news/scitech/musks-bets-on-tesla-no-human-drivers-this-year-robots-next/article_d6b99b4f-70ac-59a8-b6a6-99a2c199b108.htmlhttps://dailycaller.com/2022/01/29/elon-musk-joe-biden-electric-vehicles-tesla/https://cleantechnica.com/2022/01/28/tesla-shares-hepa-filter-demo-underlines-importance-of-clean-air/
# Error fetching URL: HTTPSConnectionPool(host='banksnews.gr', port=443): Max retries exceeded with url: /musk-and-biden-feud-all-of-the-tesla-ceos-fights-with-the-us-president/https://insideevs.com/news/563996/tesla-beats-chip-shortage-software/https://www.floridastatesman.com/news/272242278/musk-predicts-50-growth-in-tesla-sales-in-2022https://cleantechnica.com/2022/01/28/tesla-will-support-fsd-licensing-for-other-manufacturers/https://www.leprogres.fr/magazine-automobile/2022/01/29/saviez-vous-que-la-premiere-tesla-n-en-etait-pas-unehttps://www.autoevolution.com/news/canoo-may-be-making-the-same-errors-aptera-and-tesla-made-180317.htmlhttps://www.unionleader.com/news/scitech/musks-bets-on-tesla-no-human-drivers-this-year-robots-next/article_d6b99b4f-70ac-59a8-b6a6-99a2c199b108.htmlhttps://dailycaller.com/2022/01/29/elon-musk-joe-biden-electric-vehicles-tesla/https://cleantechnica.com/2022/01/28/tesla-shares-hepa-filter-demo-underlines-importance-of-clean-air/ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x790549a04440>: Failed to resolve 'banksnews.gr' ([Errno -3] Temporary failure in name resolution)"))
# Fetching (30/50): https://www.theepochtimes.com/tesla-to-delay-new-models-in-2022-for-automated-vehicle-push_4241264.htmlhttps://www.businessinsider.com.au/tesla-cybertruck-customers-frustrated-reserve-wait-worth-it-elon-musk-2022-1https://www.businessinsider.in/thelife/news/some-tesla-customers-who-paid-100-to-reserve-a-cybertruck-2-years-ago-say-theyre-frustrated-with-customer-service-but-still-prepared-to-wait/articleshow/89221798.cmshttps://www.businessinsider.com/tesla-cybertruck-customers-frustrated-reserve-wait-worth-it-elon-musk-2022-1https://insideevs.com/news/564110/tesla-semi-megachargers-fritolay-ready/
# ...
# Fetching (45/50): https://canaltech.com.br/carros/tesla-tera-de-responder-por-centenas-de-acusacoes-de-racismo-nos-eua-209041/https://www.thestar.com.my/tech/tech-news/2022/02/14/musk-pushes-the-boundaries-in-tesla-autonomous-campaignhttps://www.techtimes.com/articles/271781/20220213/tesla-fsd-ai-neural-network-features-many-layers-elon-musk%E2%80%94different.htmhttps://driving.ca/auto-news/industry/fun-police-made-elon-musk-carry-out-latest-tesla-recall-he-sayshttp://www.itechpost.com/articles/109133/20220214/polestar-polestar-2-polestar2-trailer-tesla-volkswagen-polestar2-ad-super-bowl-2022-super-bowl-ad-super-bowl-polestar.htmhttps://insideevs.com/news/652424/tesla-model-3-outsold-toyota-camry-in-california-last-year/https://www.watson.ch/digital/tesla/117706419-die-schlinge-zieht-sich-zu-kalifornien-reicht-klage-gegen-tesla-einhttps://www.mynspr.org/news/2022-02-14/california-sues-tesla-over-alleged-rampant-discrimination-against-black-employeeshttps://qz.com/tesla-buffalo-factory-workers-trying-to-unionize-1850113732https://www.davisvanguard.org/2022/02/california-civil-rights-regulator-sues-tesla-for-discrimination-against-factory-employees/https://www.euronews.com/next/2022/02/14/elon-musk-blames-the-fun-police-for-a-tesla-boombox-recall-over-safety-concernshttps://www.yahoo.com/now/tesla-autopilot-workers-seeking-unionize-new-york-131506705.html
# Fetching (46/50): http://www.hngn.com/articles/246759/20230215/tesla-open-7-500-chargers-electric-vehicles.htmhttps://www.houmatoday.com/story/news/2022/02/15/louisiana-manufacturer-ties-tesla-expands-vidalia-plant/6796713001/https://www.shrm.org/resourcesandtools/legal-and-compliance/state-and-local-updates/pages/california-sues-tesla.aspxhttps://www.oann.com/teslas-musk-donated-5044000-shares-to-charity-sec-filing/https://www.bnnbloomberg.ca/elon-musk-donated-us-5-7b-of-tesla-shares-to-charity-1.1723428https://www.politico.com/news/2023/02/15/tesla-chargers-public-electric-vehicles-00082875https://marketbusinessnews.com/tesla-starts-offering-merchandise-against-dogecoin-payments/290759/https://www.asiaone.com/money/elon-musk-donated-over-77b-tesla-shares-charityhttps://techstory.in/elon-musk-donates-5-7-billion-of-tesla-shares-to-charity/https://truthout.org/articles/tesla-may-pay-0-in-federal-taxes-this-year-according-to-its-financial-filings/https://www.dailymail.co.uk/sciencetech/article-10513389/Teslas-Musk-donated-5-5-billion-charity-Nov-SEC-filing.htmlhttps://www.eenews.net/articles/tesla-opens-its-ev-charging-network-to-the-masses/https://www.lemonde.fr/economie/article/2022/02/15/la-californie-poursuit-tesla-pour-discrimination_6113699_3234.htmlhttps://www.geo.tv/latest/399360-elon-musk-donated-over-57-billion-tesla-stock-to-charityhttps://vancouversun.com/personal-finance/high-net-worth/elon-musk-donated-us5-7-billion-of-tesla-shares-to-charity-last-november/wcm/bdca8eb3-f540-4c9b-af84-f97f0e9a9184https://www.nbcwashington.com/news/business/money-report/tesla-commits-to-open-7500-chargers-in-the-u-s-to-other-electric-vehicles-by-end-of-2024/3279867/https://www.chamberlainsun.com/musk-donated-over-5-7-billion-in-tesla-stock-to-charity-in-november/https://www.autoevolution.com/news/tesla-is-secretly-rolling-out-reverse-summon-181669.htmlhttps://www.moneyweb.co.za/news/tech/elon-musk-donated-5-7bn-of-tesla-shares-to-charity/https://www.msn.com/en-US/news/companies/elon-musk-gave-5-million-tesla-shares-to-charity-after-teasing-possible-donation-to-fight-world-hunger/ar-AATR5N2https://oglobo.globo.com/economia/elon-musk-doa-quase-us-6-bilhoes-em-acoes-da-tesla-para-caridade-25394852https://www.elsiglodetorreon.com.mx/noticia/2022/elon-musk-dona-a-la-caridad-millones-en-acciones-de-tesla.htmlhttps://www.teleamazonas.com/elon-musk-dona-millones-en-acciones-de-tesla/https://www.ellitoral.com/index.php/id_um/341155-elon-musk-dono-una-millonaria-suma-a-la-caridad-tesla-y-spacex-internacionales-tesla-y-spacex.htmlhttps://www.afr.com/wealth/people/musk-donates-8b-of-tesla-shares-to-charity-20220215-p59womhttps://www.theepochtimes.com/elon-musk-donates-nearly-2-billion-in-tesla-shares-to-charity_5059068.htmlhttps://insideevs.com/news/567663/musk-gifted-billions-tesla-shares/https://www.telemundodallas.com/tag/tesla-recall/https://www.foxbusiness.com/economy/elon-musk-billion-tesla-charityhttps://www.rashtranews.com/elon-musk-donates-5-million-tesla-shares-to-unspecified-charities-world-news/https://news.yahoo.com/tesla-hit-another-lawsuit-over-204436724.htmlhttps://www.scmp.com/tech/tech-war/article/3167146/tesla-battery-supplier-catl-said-downplay-business-risks-us-sanctions
# Fetching (47/50): https://www.extremetech.com/extreme/343173-tesla-recalls-362758-vehicles-due-to-fsd-crash-riskhttps://www.theepochtimes.com/musk-gave-out-5-7-billion-worth-of-tesla-shares-to-unknown-charity_4279884.htmlhttps://techstory.in/elon-musk-donated-5-million-tesla-shares-to-a-charity-in-november/https://www.vanityfair.com/news/2023/02/elon-musks-tesla-fires-employees-unionizehttps://www.bnnbloomberg.ca/tesla-front-runs-another-regulator-this-time-in-a-race-case-1.1724228https://borneobulletin.com.bn/elon-musk-gives-usd5-7b-in-tesla-stock-to-charity/https://menafn.com/1103703015/Elon-Musk-Donates-57-Billion-ln-Tesla-Stock-to-Charity&source=138https://www.autoworldnews.com/articles/40032/20220216/tesla-ceo-elon-musk-donated-5-7-billion-worth-companys.htmhttp://www.itechpost.com/articles/109168/20220216/fisker-ev-suv-ev-tesla-automotive-fisker-ocean-how-to-pre-order-fisker-pear.htmhttps://www.wuky.org/2022-02-15/california-sues-tesla-alleging-rampant-racism-at-factoryhttps://patch.com/california/paloalto/tesla-recalls-600k-vehicles-over-fart-bleating-goat-hornhttps://www.thedailystar.net/tech-startup/news/elon-musk-donated-over-57-bn-tesla-shares-charity-2963426https://www.thestar.com.my/tech/tech-news/2022/02/23/tesla-hit-by-another-lawsuit-over-racism-by-ex-workerhttps://www.thenewsstar.com/story/news/2022/02/15/louisiana-manufacturer-ties-tesla-expands-vidalia-plant/6796713001/https://www.msn.com/en-us/news/us/rivian-receives-opposition-to-future-factory-much-like-tesla/ar-AATWiq3https://www.marketscreener.com/business-leaders/Elon-Musk-1364/news/Musk-donated-over-5-7-billion-in-Tesla-shares-to-charity-in-Nov--39471039/https://www.phonandroid.com/elon-musk-donne-5-millions-dactions-tesla-a-une-ong-mystere.htmlhttps://zeenews.india.com/international-business/elon-musk-donates-over-5bn-worth-of-tesla-shares-to-unnamed-charity-2436946.html
# Fetching (48/50): https://www.forbes.com/sites/annakaplan/2022/02/17/elon-musk-tesla-accuse-sec-of-calculated-effort-to-chill-his-right-to-free-speech/https://www.thirdsector.co.uk/elon-musk-donated-574bn-tesla-shares-unnamed-charity/fundraising/article/1740825https://www.usatoday.com/story/money/cars/2021/06/23/tesla-model-3-top-american-car-index-ford-mustang/5312540001/https://www.rte.ie/news/business/2022/0217/1281446-tesla-letter-to-sec/https://www.washingtonexaminer.com/policy/economy/musk-accuses-sec-of-harassing-tesla-to-chill-his-criticism-of-governmenthttps://economictimes.indiatimes.com/tech/tech-bytes/tesla-sued-over-alleged-suspension-failure-in-fatal-florida-crash/articleshow/89631350.cmshttps://www.cbsnews.com/news/tesla-safety-complaints-phantom-braking-probe-nhtsa/https://www.morningstar.com/articles/1080016/tesla-investors-closely-following-discrimination-suithttps://www.cnnphilippines.com:443/business/2022/2/18/US-government-investigates-Tesla-cars-unexpected-braking.htmlhttps://www.record-eagle.com/nation_world/tesla-faces-another-us-investigation-unexpected-braking/article_8e2fdcba-5ebb-5815-8ba5-287af5100c1f.htmlhttps://www.techtimes.com/articles/271933/20220216/elon-musk-reminds-president-joe-biden-tesla-s-achievements-american.htmhttps://www.hongkongherald.com/news/272309351/report-tesla-sold-59845-chinese-made-electric-vehicles-in-januaryhttps://bnr.bg/post/101602686/amerikanskiat-regulator-prouchva-tesla-za-problemi-sas-spirachnata-sistemahttps://lasentinel.net/civil-rights-leaders-slam-tesla-after-california-charges-automaker-with-discrimination.htmlhttps://www.itnews.com.au/news/elon-musk-tesla-attack-us-sec-for-unrelenting-harassment-576222https://www.msn.com/en-xl/money/tech-and-science/tesla-phantom-braking-complaints-spurs-formal-nhtsa-probe/ar-AATZ6NShttps://www.channel3000.com/i/tesla-faces-another-us-investigation-unexpected-braking/https://katcountry989.com/2022/02/17/elon-musk-tesla-attack-sec-for-unrelenting-probe/https://abcnews.go.com/Business/wireStory/tesla-faces-us-investigation-unexpected-braking-82951683https://www.marketwatch.com/story/elon-musks-5-7-billion-secret-why-we-may-never-find-out-who-benefited-from-his-tesla-stock-donation-11645050146https://www.nbclosangeles.com/news/business/money-report/tesla-phantom-braking-complaints-elicit-nhtsa-investigation/2829047/https://www.foxbusiness.com/markets/elon-musk-tesla-sechttps://www.cnn.com/2022/02/17/cars/tesla-phantom-braking-nhtsa/https://www.middletownpress.com/news/article/Tesla-faces-another-US-investigation-unexpected-16925949.phphttps://www.numerama.com/vroom/857747-pourquoi-le-volant-yoke-de-tesla-pourrait-etre-autorise-en-france.htmlhttps://www.naveenbharat.in/tesla-sued-over-alleged-failed-suspension-in-fatal-florida-crash/https://www.cityandstateny.com/policy/2022/02/progressives-want-invest-child-care-its-tesla/362106/https://www.thedrum.com/news/2022/02/17/elon-musk-the-engine-the-tesla-brandhttps://statesville.com/lifestyles/technology/tesla-faces-another-us-investigation-unexpected-braking/article_3d29d883-c1b4-5d8f-861c-c10108256ae4.htmlhttps://www.telegraph.co.uk/world-news/2022/02/17/tesla-investigated-cars-phantom-breaking-high-speeds/https://www.digitaljournal.com/business/teslas-musk-condemned-for-hitler-tweet-as-he-rips-us-regulator/articlehttps://www.usatoday.com/story/money/cars/2022/02/16/elon-musk-tesla-stock-charity/6810992001/https://oilprice.com/Latest-Energy-News/World-News/Tesla-Faces-Regulatory-Scrutiny-Over-Braking-Defect.htmlhttps://www.thestreet.com/investing/teslas-elon-musk-sparks-another-controversyhttps://www.theepochtimes.com/elon-musk-tesla-attack-sec-for-unrelenting-harassment_4284545.html
# Fetching (49/50): https://www.shanghainews.net/news/272311206/elon-musk-donates-57-billion-in-tesla-stock-to-unknown-charityhttps://www.thetruthaboutcars.com/2022/02/nhtsa-looking-into-tesla-vehicles-over-phantom-braking/https://www.breitbart.com/tech/2022/02/17/tesla-faces-fresh-nhtsa-probe-over-phantom-braking-complaints/https://www.developpez.com/actu/331186/Elon-Musk-et-son-entreprise-Tesla-accusent-la-Securities-and-Exchange-Commission-de-les-harceler-avec-des-enquetes-interminables-et-infondees/https://www.bnnbloomberg.ca/ford-s-ceo-is-exploring-ways-to-separate-its-ev-business-to-unlock-tesla-like-value-1.1725581https://www.centralmaine.com/2022/02/17/tesla-faces-another-u-s-investigation-unexpected-braking/https://www.arkansasonline.com/news/2022/feb/18/second-probe-starts-of-teslas-autopilot/https://sg.news.yahoo.com/analysis-tesla-software-updates-allow-120730753.htmlhttps://www.deccanherald.com/business/teslas-musk-condemned-for-hitler-tweet-as-he-rips-us-regulator-1082754.htmlhttps://www.androidheadlines.com/2023/02/elon-musk-gave-1-95-billion-of-tesla-stock-to-charity-last-year.htmlhttps://www.msn.com/en-ca/money/topstories/analysis-tesla-software-updates-allow-quick-fixes-and-taking-risks/ar-AAU1Lunhttps://www.thetowntalk.com/story/news/2022/02/15/louisiana-manufacturer-ties-tesla-expands-vidalia-plant/6796713001/https://www.dailymail.co.uk/news/article-10525389/Tesla-CEO-Elon-Musk-accuses-SEC-calculated-effort-chill-right-free-speech-hounding-company.htmlhttps://www.autoevolution.com/news/gm-president-warns-elon-musk-about-tesla-s-pricing-also-says-he-admires-him-181958.htmlhttps://slate.com/technology/2022/02/tesla-fremont-racism-lawsuit-california.htmlhttps://www.freepressjournal.in/world/tesla-spacex-boss-elon-musk-lands-in-hot-water-again-after-hitler-tweethttps://theeagle.com/ap/business/tesla-faces-another-us-investigation-unexpected-braking/article_3c98c0d0-ad05-5220-8ef5-741af46ced2a.htmlhttps://www.irishtimes.com/business/manufacturing/elon-musk-and-tesla-accuse-sec-of-harassment-campaign-1.4806094https://www.erienewsnow.com/story/45899258/us-government-investigates-tesla-cars-after-reports-of-unexpected-brakinghttps://www.straitstimes.com/business/companies-markets/tesla-ceo-elon-musk-blasts-us-market-regulator-for-unrelenting-investigationhttps://www.bangkokpost.com/world/2266327/teslas-musk-condemned-for-hitler-tweet-as-he-rips-us-regulatorhttps://www.autonews.com/automakers-suppliers/teslas-software-updates-can-mean-quick-fixes-also-could-come-riskshttps://www.carscoops.com/2022/02/nhtsa-takes-official-action-in-tesla-phantom-braking-opens-preliminary-evaluation-of-416000-vehicles/https://www.bignewsnetwork.com/news/272309622/tesla-faces-another-us-investigation-unexpected-braking
# Fetching (50/50): https://www.macitynet.it/tesla-sotto-indagine-per-la-frenata-fantasma/https://www.nbcconnecticut.com/news/business/money-report/after-tesla-ceo-elon-musk-alleged-unrelenting-investigation-sec-pushes-back/2723374/https://www.msn.com/en-xl/news/other/tesla-celebrates-1-millionth-4680-cell-produced-in-january/ar-AAU44O3https://www.nbcsandiego.com/news/business/money-report/after-tesla-ceo-elon-musk-alleged-unrelenting-investigation-sec-pushes-back/2875192/https://slate.com/technology/2022/02/elon-musk-scandals-fremont-neuralink-tesla-recall.htmlhttps://www.theguardian.com/technology/2022/feb/18/tesla-california-racial-harassment-discrimination-lawsuithttps://www.news247.gr/kosmos/tesla-mayroi-ergazomenoi-katigoroyn-tin-etairia-gia-ratsismo-toys-apokaloysan-fyteia.9536482.htmlhttps://www.nbcnewyork.com/news/business/money-report/after-tesla-ceo-elon-musk-alleged-unrelenting-investigation-sec-pushes-back/3562569/https://www.nbcwashington.com/news/business/money-report/after-tesla-ceo-elon-musk-alleged-unrelenting-investigation-sec-pushes-back/2977991/https://www.journalgazette.net/business/20220219/mustang-mach-e-dethrones-teslahttps://dunyanews.tv/en/Technology/642034-Tesla-software-updates-allow-quick-fixes---and-taking-riskshttps://www.nbcphiladelphia.com/news/business/money-report/after-tesla-ceo-elon-musk-alleged-unrelenting-investigation-sec-pushes-back/3152441/https://www.msn.com/en-us/news/us/boynton-beach-man-bought-tesla-storage-batteries-for-his-solar-system-and-pays-almost-nothing-to-fpl-is-this-the-future-of-solar/ar-AAU3R1Ghttps://www.nbcchicago.com/news/business/money-report/after-tesla-ceo-elon-musk-alleged-unrelenting-investigation-sec-pushes-back/2764285/https://www.autoworldnews.com/articles/40051/20220219/tesla-vs-south-korea-korean-body-impose-penalties-carmaker-exaggerating.htmhttps://www.nbcdfw.com/news/business/money-report/after-tesla-ceo-elon-musk-alleged-unrelenting-investigation-sec-pushes-back/2895048/http://internetua.com/kompaniua-tesla-obvinili-v-rasizme
#           day                                                url  \
# 0  2022-01-01  https://www.investor.bg/novini/444/a/tesla-sys...
# 1  2022-01-02  https://www.tribuneindia.com/news/nation/india...
# 2  2022-01-03  https://www.aljazeera.com/economy/2022/1/3/tes...
# 3  2022-01-04  https://www.theverge.com/22865603/gaf-energy-t...
# 4  2022-01-05  https://zeenews.india.com/companies/meet-ashok...
#
#                                             raw_text
# 0  404 - Заявената страница не е открита! - Inves...
# 1                                  403 403 Forbidden
# 2  404 - Page not found Skip links Skip to Conten...
# 3                                        X-Forbidden
# 4  403 not available now Error 403 not available ...

# %%
# 5. Load FinBERT model for sentiment

model_name = "ProsusAI/finbert"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# pipeline will handle tokenization + model + softmax for us
finbert_pipe = pipeline(
    "text-classification",
    model=model,
    tokenizer=tokenizer,
    return_all_scores=True,   # so we get prob for pos/neg/neutral
    truncation=True,
    max_length=512            # FinBERT input limit per text
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Device set to use cpu
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/text_classification.py:111: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
# 6. Run FinBERT on each article and store a single score + topic

sent_labels = []        # "positive" / "neutral" / "negative" / "unknown" / "error"
sent_scores = []        # score for the chosen label (0–1)
topics = []             # simple topic tag based on URL

for i in range(len(url_sample)):
    text = url_sample.iloc[i]["raw_text"]
    url  = str(url_sample.iloc[i]["url"]).lower()

    # ---- (A) Simple topic from URL keywords ----
    if "tesla" in url:
        topic = "tesla"
    elif ("electric-vehicle" in url or
          "electric-vehicles" in url or
          "electric-car" in url or
          "electric-cars" in url or
          "ev-battery" in url or
          "ev-" in url):
        topic = "ev_industry"
    elif ("federal-reserve" in url or "fomc" in url or
          "interest-rate" in url or "rate-hike" in url or "rate-cut" in url or
          "inflation" in url or "cpi" in url or
          "stock-market" in url or "wall-street" in url):
        topic = "macro_market"
    else:
        topic = "other"

    topics.append(topic)

    # ---- (B) Handle missing text ----
    if not isinstance(text, str) or text.strip() == "":
        sent_labels.append("unknown")
        sent_scores.append(None)
        continue

    # ---- (C) Run FinBERT ----
    try:
        print(f"Scoring sentiment ({i+1}/{len(url_sample)})")
        result = finbert_pipe(text[:2000])   # finbert_pipe should be created with return_all_scores=True
        scores = {item["label"].lower(): item["score"] for item in result[0]}

        # best label = highest score
        best_label = max(scores, key=scores.get)
        best_score = scores[best_label]

        sent_labels.append(best_label)
        sent_scores.append(best_score)

    except Exception as e:
        print("Error scoring sentiment:", e)
        sent_labels.append("error")
        sent_scores.append(None)

# ---- (D) Attach to DataFrame ----
url_sample["topic"] = topics
url_sample["sentiment_label"] = sent_labels
url_sample["sentiment_score"] = sent_scores

# Show clean view: day, url, topic, one sentiment label + one score
url_sample[["day", "url", "topic", "sentiment_label", "sentiment_score"]].head()
# Out:
# Scoring sentiment (1/50)
# Scoring sentiment (2/50)
# Scoring sentiment (3/50)
# Scoring sentiment (4/50)
# Scoring sentiment (5/50)
# Scoring sentiment (6/50)
# Scoring sentiment (7/50)
# Scoring sentiment (8/50)
# Scoring sentiment (9/50)
# Scoring sentiment (10/50)
# Scoring sentiment (11/50)
# Scoring sentiment (12/50)
# Scoring sentiment (13/50)
# Scoring sentiment (14/50)
# Scoring sentiment (15/50)
# Scoring sentiment (16/50)
# Scoring sentiment (17/50)
# Scoring sentiment (18/50)
# Scoring sentiment (19/50)
# Scoring sentiment (20/50)
# Scoring sentiment (21/50)
# Scoring sentiment (22/50)
# Scoring sentiment (23/50)
# Scoring sentiment (24/50)
# Scoring sentiment (25/50)
# Scoring sentiment (26/50)
# Scoring sentiment (27/50)
# Scoring sentiment (28/50)
# Scoring sentiment (30/50)
# Scoring sentiment (31/50)
# Scoring sentiment (32/50)
# Scoring sentiment (33/50)
# Scoring sentiment (34/50)
# Scoring sentiment (35/50)
# Scoring sentiment (36/50)
# Scoring sentiment (37/50)
# Scoring sentiment (38/50)
# Scoring sentiment (39/50)
# Scoring sentiment (40/50)
# Scoring sentiment (41/50)
# Scoring sentiment (42/50)
# Scoring sentiment (43/50)
# Scoring sentiment (44/50)
# Scoring sentiment (45/50)
# Scoring sentiment (46/50)
# Scoring sentiment (47/50)
# Scoring sentiment (48/50)
# Scoring sentiment (49/50)
# Scoring sentiment (50/50)
#           day                                                url  topic  \
# 0  2022-01-01  https://www.investor.bg/novini/444/a/tesla-sys...  tesla
# 1  2022-01-02  https://www.tribuneindia.com/news/nation/india...  tesla
# 2  2022-01-03  https://www.aljazeera.com/economy/2022/1/3/tes...  tesla
# 3  2022-01-04  https://www.theverge.com/22865603/gaf-energy-t...  tesla
# 4  2022-01-05  https://zeenews.india.com/companies/meet-ashok...  tesla
#
#   sentiment_label  sentiment_score
# 0         neutral         0.858641
# 1         neutral         0.927861
# 2         neutral         0.875107
# 3         neutral         0.923561
# 4         neutral         0.923023

# %%
url_sample.to_csv("tsla_event_urls_with_sentiment.csv", index=False)
print("Saved sentiment results to tsla_event_urls_with_sentiment.csv")
# Out:
# Saved sentiment results to tsla_event_urls_with_sentiment.csv

# %% [markdown]
# ### Problem 3: The Model Development Part  (20 points)
#
# **Insert your answers in the cell below**
#
# **Add as many cells as needed**
#
# Use one of the conjectures as the basis to create a model so that other teams in the company can use your model for new unseen data.

# %% [markdown]
# ### Problem 4: Presentation in the class (15 mins and 10 points)
#
# * (5 points) Present your slides in the class.
# * (5 points) Participate in peer review process.
#
# Suggestion: You should practice so that your presentation does not exceed 10 minutes. All members of a group should share equal responsibility to present. **Points may be taken away if presentation exceeds 10 mins.**

# %% [markdown]
# # Report: communicate the results (20 points (or 25 points))
#
# ** minimum 8 pages **
#
# (1) (5 points) What is your business proposition?
#
# (2) (3 points) Why this topic is interesting or important to you? (Motivations)
#
# (3) (5 points) How did you analyse the data? What conjectures you made? Which conjecture you used as the basis of developing your model? Why?
#
# (4) (3 points) How does your analysis support your business proposition?
# (please include figures or tables in the report, but no source code)
#
# (5) (4 points) How does the model tie in with the business proposition?
#
# (5) (bonus 5 points) How did your team work together as a group from ideation to implementaion? Write in one page.

# %% [markdown]
# # Slides (for 10 minutes of presentation) (10 points)
#
#
# 1. (2 points) Motivation about the data collection, why the topic is interesting to you.
#
#
# 2. (3 points) Conjectures you made. Reasons behind choosing a particular conjecture for the basis of developing a model.
#
#
# 2. (3 points) Communicating Results (figure/table)
#
#
# 4. (2 points) Story telling (How all the parts (data, analysis, result) fit together as a story?)

# %% [markdown]
# # Done
#
# All set!
#
# **What do you need to submit?**
#
# * **Notebook File**: Save this IPython notebook, and find the notebook file in your folder (for example, "groupname.ipynb"). This is the file you need to submit. Please make sure all the plotted tables and figures are in the notebook.
#
# * **PPT Slides**
#
# * **Report**
#
# Put the Jupyter Notebook file, the report (in PDF) and PPT slides (converted to PDF) in a folder. Zip the folder. After zipping, it should have the extension .zip. The name of the .zip file should be casestudy_4_groupname.zip. Upload the .zip file on Canvas.
#
# **Note: Each team just needs to make one submission**
